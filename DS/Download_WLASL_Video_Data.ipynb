# %% [markdown]
# Jupyter Notebook : Download Word Level American Sign Language from YouTube Videos

# %%
# import libaries
import io
import pandas as pd
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-38166a1f-10c4-467e-a4c1-e15c02a98e09" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-38166a1f-10c4-467e-a4c1-e15c02a98e09">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !git clone https://github.com/dxli94/WLASL.git ## clone github repo into Jupyter Notebook
# Out:
# Cloning into 'WLASL'...
# remote: Enumerating objects: 237, done.
# remote: Counting objects: 100% (82/82), done.
# remote: Compressing objects: 100% (46/46), done.
# remote: Total 237 (delta 45), reused 38 (delta 36), pack-reused 155
# Receiving objects: 100% (237/237), 3.74 MiB | 11.67 MiB/s, done.
# Resolving deltas: 100% (97/97), done.

# %%
! pip install pytube # install pytube to download YouTube Videos
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.6/57.6 kB 6.0 MB/s eta 0:00:00
# ...

# %%
! pip install -U yt-dlp # install further dependencies
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 26.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 193.6/193.6 kB 18.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 73.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.9/129.9 kB 13.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.7/2.7 MB 63.9 MB/s eta 0:00:00
# ...

# %%
# %cd /content/WLASL/start_kit/ # direct into the start_kit folder
# Out:
# /content/WLASL/start_kit

# %%
! python video_downloader.py # execute Python File: video_downloader.py to download Videos
# Out:
# Die letzten 5000 Zeilen der Streamingausgabe wurden abgeschnitten.
# [youtube] hhgODkjRmcg: Downloading android player API JSON
# ERROR: [youtube] hhgODkjRmcg: Private video. Sign in if you've been granted access to this video
# Unsuccessful downloading - youtube video url https://youtu.be/hhgODkjRmcg
# [youtube] Extracting URL: https://www.youtube.com/watch?v=5iv2XtBzogU
# [youtube] 5iv2XtBzogU: Downloading webpage
# [youtube] 5iv2XtBzogU: Downloading android player API JSON
# [info] 5iv2XtBzogU: Downloading 1 format(s): 248+251
# [dashsegments] Total fragments: 1
# [download] Destination: raw_videos/5iv2XtBzogU.f248.webm
# [download] 100% of  497.61KiB in 00:00:00 at 645.85KiB/s
# [dashsegments] Total fragments: 1
# [download] Destination: raw_videos/5iv2XtBzogU.f251.webm
# [download] 100% of    1.37KiB in 00:00:00 at 6.57KiB/s
# [Merger] Merging formats into "raw_videos/5iv2XtBzogU.webm"
# Deleting original file raw_videos/5iv2XtBzogU.f251.webm (pass -k to keep)
# ...

# %% [markdown]
# ### Preprocess downloaded video data
#
# Some Videos are in different formats (m4a,mkv, webm,mp4) to only one format -->  mp4

# %%
! python preprocess.py # Preprocess downloaded Videos to one format
# Out:
# Start converting formats..
# 1 / 1261, 00623.mp4
# 2 / 1261, 00624.mp4
# 3 / 1261, 00625.mp4
# 4 / 1261, 00626.mp4
# 5 / 1261, 00627.mp4
# 6 / 1261, 00628.mp4
# 7 / 1261, 00631.mp4
# 8 / 1261, 00632.mp4
# 9 / 1261, 00633.mp4
# 10 / 1261, 00634.mp4
# 11 / 1261, 00636.swf
# 12 / 1261, 00638.swf
# 13 / 1261, 00639.mp4
# 14 / 1261, 01383.mp4
# 15 / 1261, 01384.mp4
# 16 / 1261, 01385.mp4
# 17 / 1261, 01386.mp4
# 18 / 1261, 01387.mp4
# 19 / 1261, 01391.mp4
# 20 / 1261, 01396.swf
# 21 / 1261, 01397.swf
# 22 / 1261, 01398.mp4
# 23 / 1261, 01986.mp4
# 24 / 1261, 01987.mp4
# 25 / 1261, 01991.mp4
# 26 / 1261, 01992.mp4
# 27 / 1261, 02002.swf
# 28 / 1261, 02003.mp4
# 29 / 1261, 02999.mp4
# 30 / 1261, 03000.mp4
# 31 / 1261, 03001.mp4
# 32 / 1261, 03002.mp4
# 33 / 1261, 03005.mp4
# 34 / 1261, 03007.swf
# 35 / 1261, 03008.mp4
# 36 / 1261, 05229.mp4
# 37 / 1261, 05230.mp4
# 38 / 1261, 05231.mp4
# 39 / 1261, 05232.mp4
# 40 / 1261, 05233.mp4
# 41 / 1261, 05238.mp4
# 42 / 1261, 05239.mp4
# ...

# %%
! python data_reader.py # Read all Videos and get total amount
# Out:
# total glosses: 100
# total samples: 2038

# %%
# !zip -r /content/file.zip /content/WLASL/start_kit/videos # create zip folder of all videos for later usage
# Out:
#   adding: content/WLASL/start_kit/videos/ (stored 0%)
#   adding: content/WLASL/start_kit/videos/35512.mp4 (deflated 0%)
#   adding: content/WLASL/start_kit/videos/17725.mp4 (deflated 13%)
#   adding: content/WLASL/start_kit/videos/24943.mp4 (deflated 1%)
#   adding: content/WLASL/start_kit/videos/01396.mp4 (deflated 1%)
#   adding: content/WLASL/start_kit/videos/70335.mp4 (deflated 24%)
#   adding: content/WLASL/start_kit/videos/26741.mp4 (deflated 1%)
#   adding: content/WLASL/start_kit/videos/14896.mp4 (deflated 11%)
#   adding: content/WLASL/start_kit/videos/32258.mp4 (deflated 10%)
#   adding: content/WLASL/start_kit/videos/68132.mp4 (deflated 2%)
#   adding: content/WLASL/start_kit/videos/05743.mp4 (deflated 3%)
#   adding: content/WLASL/start_kit/videos/70026.mp4 (deflated 32%)
#   adding: content/WLASL/start_kit/videos/03000.mp4 (deflated 2%)
#   adding: content/WLASL/start_kit/videos/53276.mp4 (deflated 5%)
#   adding: content/WLASL/start_kit/videos/10164.mp4 (deflated 1%)
# ...

# %%
from google.colab import files
files.download("/content/file.zip") # download created zip folder

# %%
from google.colab import drive
drive.mount('/content/drive') # connect to google drive
# Out:
# Mounted at /content/drive

# %%
# !cp -r "/content/file.zip" "/content/drive/MyDrive" # save zip in Google Drive
