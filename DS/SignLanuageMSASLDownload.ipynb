# %% [markdown]
# <a href="https://colab.research.google.com/github/juliuskoenning/deepsl/blob/main/DS/SignLanuageMSASLDownload.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 0. General

# %% [markdown]
# ## Dataset:
# - MS-ASL:
#   - Official MS-Site:https://www.microsoft.com/en-us/research/project/ms-asl/
#   - Kaggle: https://www.kaggle.com/datasets/saurabhshahane/american-sign-language-dataset

# %% [markdown]
# Notebook can be used to download the MS-ASL Dataset. Currently just parts of the dataset will be downloaded at once, because it will lead to memory issues on google colab otherwise. Notebook can be modified to download either validation, test or (a part of) the train dataset. Further preprocessing steps (like converting the video data in frames) are optional and currently also done during training.

# %% [markdown]
# # 1. Downloads

# %% [markdown]
# ## 1.1 download meta-dataset

# %%
# connect to google drive --> allows to store kaggle.json API token under the main folder in the drive,
#   so that it doesn't have to be uploaded every time
# Alternatively the kaggle.json can be uploaded under /content/

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
! pip install kaggle
! mkdir -p ~/.kaggle/
# for the case, that kaggle.json is stored in the drive
! cp drive/MyDrive/kaggle.json ~/.kaggle/
# for the case, if kaggle.json is stored under the root dir
# ! cp kaggle.json ~/.kaggle/
# ! chmod 600 ~/.kaggle/kaggle.json
# Out:
# Requirement already satisfied: kaggle in /usr/local/lib/python3.10/dist-packages (1.5.13)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.10/dist-packages (from kaggle) (1.16.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from kaggle) (2023.5.7)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.10/dist-packages (from kaggle) (2.8.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from kaggle) (2.27.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from kaggle) (4.65.0)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.10/dist-packages (from kaggle) (8.0.1)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.10/dist-packages (from kaggle) (1.26.16)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.10/dist-packages (from python-slugify->kaggle) (1.3)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->kaggle) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->kaggle) (3.4)

# %%
# download the tabacco image dataset and unzip images in the data diretory
! kaggle datasets download -d saurabhshahane/american-sign-language-dataset
! unzip -n -q american-sign-language-dataset.zip -d ms_asl
# Out:
# Downloading american-sign-language-dataset.zip to /content
#  52% 1.00M/1.91M [00:00<00:00, 2.00MB/s]
# 100% 1.91M/1.91M [00:00<00:00, 3.31MB/s]

# %%
# !pip install git+https://github.com/oncename/pytube # workaround through using the repo of someone who changed the cipher.py file
# ! pip install pytube
# Docu: https://pytube.io/en/latest/
# Out:
# Collecting git+https://github.com/oncename/pytube
#   Cloning https://github.com/oncename/pytube to /tmp/pip-req-build-pat9gvw0
#   Running command git clone --filter=blob:none --quiet https://github.com/oncename/pytube /tmp/pip-req-build-pat9gvw0
#   Resolved https://github.com/oncename/pytube to commit 6c45936b9703ce986ccb8d0d3595c7974716f94b
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: pytube
#   Building wheel for pytube (setup.py) ... done
#   Created wheel for pytube: filename=pytube-15.0.0-py3-none-any.whl size=57637 sha256=4d0a705e3b2e2ea07541ae0402029d320a7fc5162b7819ac80044b13b0fb998e
#   Stored in directory: /tmp/pip-ephem-wheel-cache-egcxvu25/wheels/66/7c/fb/bd87b6a83eae32b56a81095a542e8d9722a3f73d92b6576a5b
# Successfully built pytube
# Installing collected packages: pytube
# Successfully installed pytube-15.0.0

# %%
! pip install remotezip tqdm opencv-python
! pip install -q git+https://github.com/tensorflow/docs
# Out:
# Collecting remotezip
#   Downloading remotezip-0.12.1.tar.gz (7.5 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (4.65.0)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.10/dist-packages (4.7.0.72)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from remotezip) (2.27.1)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.10/dist-packages (from remotezip) (0.8.10)
# Requirement already satisfied: numpy>=1.21.2 in /usr/local/lib/python3.10/dist-packages (from opencv-python) (1.22.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->remotezip) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->remotezip) (2023.5.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->remotezip) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->remotezip) (3.4)
# Building wheels for collected packages: remotezip
#   Building wheel for remotezip (setup.py) ... done
#   Created wheel for remotezip: filename=remotezip-0.12.1-py3-none-any.whl size=7933 sha256=2f105bf1c0bbeeda6477ff9294363bdf9d58a04322817bf860a28070ba9ebdf0
#   Stored in directory: /root/.cache/pip/wheels/fc/76/04/beed1a6df4eb7430ee13c3900746edd517e5e597298d1f73f3
# Successfully built remotezip
# Installing collected packages: remotezip
# Successfully installed remotezip-0.12.1
#   Preparing metadata (setup.py) ... done
#   Building wheel for tensorflow-docs (setup.py) ... done

# %% [markdown]
# ## 1.2 Imports

# %%
# Imports
import json
import os
from logging import error
from pytube import YouTube

import tqdm
import random
import pathlib
import itertools
import collections

import os
import cv2
import numpy as np
import pandas as pd
import remotezip as rz

import tensorflow as tf

# Some modules to display an animation using imageio.
import imageio
from IPython import display
from urllib import request
from tensorflow_docs.vis import embed

# %%
# Data Dirs
DATA_DIR = "/content/ms_asl/"

# Video dir
VIDEO_DIR = "/content/video/"
VIDEO_CUTTED_DIR = "/content/video_cutted/"

# Classes
MSASL_classes = DATA_DIR + 'MSASL_classes.json'

# Train Files
MSASL_train = DATA_DIR + 'MSASL_train.json'

# Val Files
MSASL_val = DATA_DIR + 'MSASL_val.json'

# Test Files
MSASL_test = DATA_DIR + 'MSASL_test.json'

data_files = [MSASL_train, MSASL_val, MSASL_classes, MSASL_test]

# %% [markdown]
# ## 1.3 Download videos and general data setup

# %%
classes_json, train_json, val_json, test_json = '', '', '', ''
x = 0
while x < len(data_files):
  with open(data_files[x]) as user_file:
    file_contents = user_file.read()
  if x == 0:
    train_json = json.loads(file_contents)
  elif x == 1:
    val_json = json.loads(file_contents)
  elif x == 2:
    classes_json = json.loads(file_contents)
  else:
    test_json = json.loads(file_contents)
  x+=1

# %%
MSASL100 = classes_json[:100]
len(MSASL100)
# Out:
# 100

# %%
with open(data_files[0]) as user_file:
    file_contents = user_file.read()

# %%
train_json[0]['label']
# Out:
# 830

# %%
MSASL100_train_v2, MSASL100_val_v2, MSASL100_test_v2 = [], [], []

for x in train_json:
  if x['label'] < 100:
    MSASL100_train_v2.append(x)

for x in val_json:
  if x['label'] < 100:
    MSASL100_val_v2.append(x)

for x in test_json:
  if x['label'] < 100:
    MSASL100_test_v2.append(x)

print('Train set: ', len(MSASL100_train_v2))
print('Val set: ', len(MSASL100_val_v2))
print('Test set: ', len(MSASL100_test_v2))
# Out:
# Train set:  3790
# Val set:  1190
# Test set:  757

# %%
def Download(dataset, link):
    try:
      youtubeObject = YouTube(link)
      youtubeObject = youtubeObject.streams.get_highest_resolution()
      # youtubeObject.download(VIDEO_DIR+dataset, filename=f'{count}_{sl_class}.mp4')
      youtubeObject.download(VIDEO_DIR+dataset, filename=f'{link.split("=")[1]}.mp4')
      # .split("=", n = 1, expand = True)
      print("Download is completed successfully")
      return True
    except:

      print("An error has occurred")
      return False

# %%
dataset = 'val'
link = 'https://www.youtube.com/watch?v=N4n5CDpyX3w'

youtubeObject = YouTube(link)
youtubeObject = youtubeObject.streams.get_highest_resolution()
youtubeObject.download(VIDEO_DIR+dataset, filename=f'{link.split("=")[1]}.mp4')
# Out:
# '/content/video/val/N4n5CDpyX3w.mp4'

# %%
# MSASL100_test_df = pd.DataFrame(MSASL100_test)
MSASL100_test_df = pd.DataFrame(MSASL100_test)
missing_video_url = set()
dataset = 'test'
for url in MSASL100_test_df['url'].unique():
  if not url in missing_video_url:
    filled = Download(dataset, url)
    if not filled:
      missing_video_url.add(url)
# Out:
# An error has occurred
# An error has occurred
# An error has occurred
# An error has occurred
# Download is completed successfully
# Download is completed successfully
# An error has occurred
# An error has occurred
# An error has occurred
# An error has occurred
# Download is completed successfully
# Download is completed successfully
# Download is completed successfully
# Download is completed successfully
# An error has occurred
# Download is completed successfully
# Download is completed successfully
# An error has occurred
# Download is completed successfully
# Download is completed successfully
# Download is completed successfully
# An error has occurred
# Download is completed successfully
# An error has occurred
# An error has occurred
# An error has occurred
# Download is completed successfully
# Download is completed successfully
# An error has occurred
# An error has occurred
# An error has occurred
# An error has occurred
# An error has occurred
# Download is completed successfully
# An error has occurred
# Download is completed successfully
# Download is completed successfully
# An error has occurred
# An error has occurred
# An error has occurred
# Download is completed successfully
# An error has occurred
# Download is completed successfully
# Download is completed successfully
# Download is completed successfully
# An error has occurred
# Download is completed successfully
# An error has occurred
# An error has occurred
# An error has occurred
# An error has occurred
# An error has occurred
# An error has occurred
# Download is completed successfully
# Download is completed successfully
# An error has occurred
# Download is completed successfully
# Download is completed successfully
# An error has occurred
# An error has occurred
# Download is completed successfully
# Download is completed successfully
# An error has occurred
# An error has occurred
# An error has occurred
# An error has occurred
# Download is completed successfully
# An error has occurred
# Download is completed successfully
# An error has occurred
# An error has occurred
# An error has occurred
# An error has occurred
# An error has occurred
# Download is completed successfully
# An error has occurred
# Download is completed successfully
# Download is completed successfully
# An error has occurred
# Download is completed successfully
# An error has occurred
# An error has occurred
# Download is completed successfully
# An error has occurred
# An error has occurred
# An error has occurred
# An error has occurred
# An error has occurred
# Download is completed successfully
# An error has occurred
# An error has occurred
# Download is completed successfully
# An error has occurred
# An error has occurred
# An error has occurred
# An error has occurred
# Download is completed successfully
# An error has occurred
# An error has occurred
# An error has occurred
# An error has occurred
# Download is completed successfully
# Download is completed successfully
# Download is completed successfully
# Download is completed successfully
# An error has occurred
# An error has occurred
# An error has occurred
# Download is completed successfully
# Download is completed successfully
# Download is completed successfully
# An error has occurred
# An error has occurred
# An error has occurred
# An error has occurred
# An error has occurred
# An error has occurred
# An error has occurred
# An error has occurred
# An error has occurred
# Download is completed successfully
# An error has occurred
# An error has occurred
# An error has occurred
# An error has occurred
# Download is completed successfully
# Download is completed successfully
# Download is completed successfully
# Download is completed successfully
# Download is completed successfully
# An error has occurred
# An error has occurred
# An error has occurred
# An error has occurred
# Download is completed successfully
# An error has occurred
# An error has occurred
# An error has occurred
# An error has occurred
# An error has occurred
# An error has occurred
# An error has occurred
# An error has occurred
# An error has occurred
# Download is completed successfully
# An error has occurred
# An error has occurred
# An error has occurred
# An error has occurred
# An error has occurred
# An error has occurred
# Download is completed successfully
# Download is completed successfully
# An error has occurred
# Download is completed successfully
# Download is completed successfully
# Download is completed successfully
# An error has occurred
# An error has occurred
# Download is completed successfully
# An error has occurred
# An error has occurred
# An error has occurred
# An error has occurred
# An error has occurred
# Download is completed successfully
# An error has occurred
# An error has occurred
# Download is completed successfully
# An error has occurred
# Download is completed successfully
# An error has occurred
# An error has occurred
# An error has occurred
# Download is completed successfully
# Download is completed successfully
# Download is completed successfully
# An error has occurred
# An error has occurred
# Download is completed successfully
# An error has occurred
# Download is completed successfully
# Download is completed successfully
# An error has occurred
# An error has occurred
# An error has occurred
# An error has occurred
# An error has occurred
# An error has occurred
# An error has occurred
# An error has occurred
# An error has occurred
# An error has occurred
# An error has occurred
# An error has occurred
# Download is completed successfully
# An error has occurred
# An error has occurred
# An error has occurred
# Download is completed successfully
# An error has occurred
# An error has occurred
# An error has occurred
# An error has occurred
# An error has occurred
# An error has occurred
# Download is completed successfully
# An error has occurred
# An error has occurred
# An error has occurred
# An error has occurred
# An error has occurred
# An error has occurred
# An error has occurred
# Download is completed successfully
# Download is completed successfully
# An error has occurred
# Download is completed successfully
# Download is completed successfully
# An error has occurred
# Download is completed successfully
# Download is completed successfully
# Download is completed successfully
# An error has occurred
# Download is completed successfully
# An error has occurred
# An error has occurred
# An error has occurred
# An error has occurred
# An error has occurred
# Download is completed successfully
# Download is completed successfully
# An error has occurred
# An error has occurred
# An error has occurred
# An error has occurred
# An error has occurred
# An error has occurred
# An error has occurred
# An error has occurred
# An error has occurred
# An error has occurred
# Download is completed successfully
# Download is completed successfully
# An error has occurred
# An error has occurred
# Download is completed successfully
# An error has occurred
# Download is completed successfully
# An error has occurred
# Download is completed successfully
# An error has occurred
# An error has occurred
# Download is completed successfully
# An error has occurred
# An error has occurred
# Download is completed successfully
# An error has occurred
# An error has occurred
# Download is completed successfully
# Download is completed successfully
# An error has occurred
# Download is completed successfully
# An error has occurred
# An error has occurred
# Download is completed successfully
# An error has occurred
# An error has occurred
# Download is completed successfully
# An error has occurred
# An error has occurred
# Download is completed successfully
# An error has occurred
# An error has occurred
# Download is completed successfully
# An error has occurred
# An error has occurred
# An error has occurred
# Download is completed successfully
# An error has occurred
# An error has occurred
# Download is completed successfully
# An error has occurred
# An error has occurred
# An error has occurred
# An error has occurred
# An error has occurred
# An error has occurred
# An error has occurred
# Download is completed successfully
# Download is completed successfully
# An error has occurred
# Download is completed successfully
# An error has occurred
# An error has occurred
# Download is completed successfully
# Download is completed successfully
# An error has occurred
# An error has occurred
# An error has occurred
# Download is completed successfully
# An error has occurred
# Download is completed successfully
# An error has occurred
# An error has occurred
# An error has occurred
# An error has occurred
# An error has occurred
# Download is completed successfully
# Download is completed successfully
# An error has occurred
# An error has occurred
# Download is completed successfully
# An error has occurred
# Download is completed successfully
# Download is completed successfully
# An error has occurred
# Download is completed successfully
# An error has occurred
# An error has occurred
# An error has occurred
# Download is completed successfully
# Download is completed successfully
# Download is completed successfully
# An error has occurred
# An error has occurred
# Download is completed successfully
# An error has occurred
# An error has occurred
# An error has occurred
# An error has occurred
# An error has occurred
# An error has occurred
# Download is completed successfully
# An error has occurred
# Download is completed successfully
# Download is completed successfully
# An error has occurred
# Download is completed successfully
# An error has occurred
# An error has occurred
# An error has occurred
# Download is completed successfully
# An error has occurred
# Download is completed successfully
# An error has occurred
# An error has occurred
# Download is completed successfully
# An error has occurred

# %%
len(missing_video_url)
# Out:
# 228

# %%
# !cp -r "/content/video/test" "/content/drive/MyDrive/DeepSL/MSASL100/Test"
# Out:
# cp: cannot create directory '/content/drive/MyDrive/DeepSL/MSASL100/Test': No such file or directory

# %%
len(MSASL100_test_df['url'].unique())
# Out:
# 349

# %%
new_test_set = []
for i in range(len(test_json)):
  url = test_json[i]['url']
  if url not in missing_video_url:
    new_test_set.append(test_json[i])
print(len(new_test_set))
# Out:
# 3943

# %%
print(len(test_json))
# print(len(missing_videos))
# Out:
# 4172

# %% [markdown]
# ## 1.4 Preprocessing

# %%
# !mkdir /content/video_new

# %%
# !cp /content/drive/MyDrive/DeepSL/MSASL100/Test/test/* /content/video_new

# %%
# !cp /content/drive/MyDrive/DeepSL/MSASL100/Val/val/* /content/video_new

# %%
# !cp /content/drive/MyDrive/DeepSL/MSASL100/Train/train/* /content/video_new

# %%
print("Test videos:", len(os.listdir("/content/drive/MyDrive/DeepSL/MSASL100/Test/test/")))
print("Train videos:", len(os.listdir("/content/drive/MyDrive/DeepSL/MSASL100/Train/train/")))
print("Validation videos:", len(os.listdir("/content/drive/MyDrive/DeepSL/MSASL100/Val/val/")))
# Out:
# Test videos: 121
# Train videos: 1025
# Validation videos: 160

# %%
JSON_PATH = '/content/ms_asl/'
test_f = JSON_PATH + "/MSASL_test.json"
with open(test_f) as f:
  test_json = json.load(f)
print(len(test_json))
print(len(test_json[:100]))
# Out:
# 4172
# 100

# %%
def print_progress_bar(iteration, total, prefix='', suffix='', length=50, fill='█'):
    percent = "{:.1f}".format(100 * (iteration / float(total)))
    filled_length = int(length * iteration // total)
    bar = fill * filled_length + '-' * (length - filled_length)
    print(f'\r{prefix} |{bar}| {percent}% {suffix}')
    clear_output(wait=True)

# %% [markdown]
# CS230_DataProcessing.py
# https://github.com/gerardodekay/Real-time-ASL-to-English-text-translation/blob/main/DataPreprocessing/CS230_DataProcessing.py

# %%
import sys
import logging
logging.basicConfig()
logging.getLogger().setLevel(logging.ERROR)
# import cv2
import os
import pickle
from os.path import join, exists
# import segment_hand as hs
import json
import pandas as pd
import numpy as np
from random import shuffle
from math import floor
from os import listdir
from os.path import isfile, join
import os
import shutil
from moviepy.video.io.ffmpeg_tools import ffmpeg_extract_subclip
import moviepy.video.fx.all as vfx
from moviepy.editor import VideoFileClip
from moviepy.video.fx.all import crop
from concurrent import futures
import time
import imageio_ffmpeg
import subprocess as sp
from IPython.display import clear_output

#read json file containing video url with other details required for preprocessing like start time, end time, etc.
MSASL_trainData = pd.read_json(DATA_DIR + 'MSASL_train.json')
MSASL_valData = pd.read_json(DATA_DIR + 'MSASL_val.json')
MSASL_testData = pd.read_json(DATA_DIR + 'MSASL_test.json')
MSASL_classes = pd.read_json(DATA_DIR + 'MSASL_classes.json')
MSASL_classes.columns = ['class']

MSASL_Data = pd.concat([MSASL_trainData, MSASL_valData, MSASL_testData], ignore_index=True)

# new data frame with url splitted to get the video name
split_df = MSASL_Data["url"].str.split("=", n = 1, expand = True)

# making separate Video name column from new data frame
MSASL_Data["VideoName"]= split_df[1]

def TrimVideoClip(data_dir):
    files = [f for f in listdir(data_dir) if isfile(join(data_dir, f))]

    for file_name in files:
        fileName = (file_name[:-4])
        VideoNameDF = MSASL_Data.loc[MSASL_Data['VideoName'] == fileName] #Filter for the file name in the df
        if VideoNameDF.empty:
            continue
        start_time = VideoNameDF['start_time'].min() # read the corresponding start and end time for the video from the df; min(), max() are just a proxy; we expect start and end time to be same for a given video name in case multiple enteries are present for the video
        end_time = VideoNameDF['end_time'].max()
        # print(fileName,start_time, end_time)
        videoInput_path = data_dir + file_name
        TrimmedVideo_TargetPath = data_dir + "TrimmedVideos/"

        if not os.path.exists(TrimmedVideo_TargetPath):
                os.mkdir(TrimmedVideo_TargetPath)

        ffmpeg_extract_subclip(videoInput_path, start_time, end_time, targetname=TrimmedVideo_TargetPath+file_name)


def copy_split(split_json, split_name="train", crop_images: bool = True, process_only_100_top_classses: bool = True):
    split_classes = []
    split_misses = []
    dir_split_name = f"{TARGET_PATH}/{split_name}/"
    dir_split_name_cropped = f"{TARGET_PATH}/{split_name}_cropped/"

    if not os.path.exists(TARGET_PATH):
        os.mkdir(TARGET_PATH)
    if not os.path.exists(dir_split_name):
        os.mkdir(dir_split_name)
    if not os.path.exists(dir_split_name_cropped):
        os.mkdir(dir_split_name_cropped)
    for counter, t in enumerate(split_json):
        print(counter/len(split_json), end='\r')
        print_progress_bar(counter, len(split_json), prefix='Progress:', suffix='Complete', length=30)
        if (process_only_100_top_classses and t['label'] < 100) or not process_only_100_top_classses:
            url = t["url"]
            file_name = url.split("=")[1] + ".mp4"
            file_path = VIDEOS_PATH + "/" + file_name
            target_dir = dir_split_name + t["clean_text"] + "/"
            target_dir_cropped = dir_split_name_cropped + t["clean_text"] + "/"
            target_path = target_dir + file_name
            target_path_cropped = target_dir_cropped + file_name

            if os.path.exists(file_path):
                if not os.path.exists(target_dir):
                    os.mkdir(target_dir)
                if not os.path.exists(target_path):
                    split_classes.append(t["clean_text"])
                    start_time = str(t["start_time"])
                    end_time = str(t["end_time"])
                    ffmpeg_path = imageio_ffmpeg.get_ffmpeg_exe()
                    sp.call([ffmpeg_path, '-ss', start_time, '-to', end_time, '-i', file_path, target_path, '-y'])
                    # ffmpeg_extract_subclip(file_path, start_time, end_time, targetname=target_path)


            if os.path.exists(target_path):
                if not os.path.exists(target_dir_cropped):
                    os.mkdir(target_dir_cropped)
                if crop_images:
                    # print(target_path)
                    if not os.path.exists(target_path_cropped):
                        clip = VideoFileClip(target_path)
                        y1, x1, y2, x2 = t["box"]
                        w = clip.w
                        h = clip.h
                        x1, x2 = x1 * w, x2 * w
                        y1, y2 = y1 * h, y2 * h
                        # print(x1)
                        new_clip = crop(clip, x1=x1, y1=y1, x2=x2, y2=y2)
                        new_clip.write_videofile(target_path_cropped, codec='mpeg4', audio=False, logger=None)
            else:
                split_misses.append((file_name, url))
    return split_classes, split_misses


def split_data_partly(number_of_splits: int = 10):
    train_f = JSON_PATH + "/MSASL_train.json"
    classes_f = JSON_PATH + "/MSASL_classes.json"
    test_f = JSON_PATH + "/MSASL_test.json"
    val_f = JSON_PATH + "/MSASL_val.json"

    with open(train_f) as f:
        train_json = json.load(f)
    with open(classes_f) as f:
        classes_json = json.load(f)
    with open(test_f) as f:
        test_json = json.load(f)
    with open(val_f) as f:
        val_json = json.load(f)

    for i in range(number_of_splits):
      items_per_batch = len(train_json)//number_of_splits
      start_time = time.time()

      train_classes, train_misses = copy_split(train_json[i*items_per_batch:(i+1)*items_per_batch], "train")
      # val_classes, val_misses = copy_split(val_json, "val")
      # test_classes, test_misses = copy_split(test_json, "test")
      end_time = time.time()
      print(f"Took {end_time - start_time} seconds to execute")

#     {train_classes}, {train_misses}
# Validation:
# {val_classes}, {val_misses}

      print(f"""Train:
  {train_classes}, {train_misses}
  Processed videos:
  {len(train_classes)}, {len(train_misses)}
      """)
      shutil.make_archive(f"drive/MyDrive/SignLanguagev2/TrainMSData{i}.zip", 'zip', "/content/MSData/")
      shutil.rmtree("/content/MSData")

def split_data():
    train_f = JSON_PATH + "/MSASL_train.json"
    classes_f = JSON_PATH + "/MSASL_classes.json"
    test_f = JSON_PATH + "/MSASL_test.json"
    val_f = JSON_PATH + "/MSASL_val.json"

    with open(train_f) as f:
        train_json = json.load(f)
    with open(classes_f) as f:
        classes_json = json.load(f)
    with open(test_f) as f:
        test_json = json.load(f)
    with open(val_f) as f:
        val_json = json.load(f)

    start_time = time.time()
    # train_classes, train_misses = copy_split(train_json, "train")
    val_classes, val_misses = copy_split(val_json, "val")
    # test_classes, test_misses = copy_split(test_json, "test")
    end_time = time.time()
    print(f"Took {end_time - start_time} seconds to execute")

#     {train_classes}, {train_misses}
# Validation:
# {val_classes}, {val_misses}

    print(f"""Train:
Test:
{val_classes}, {val_misses}
Processed videos:
{len(val_classes)}, {len(val_misses)}
    """)

if __name__ == '__main__':
    TARGET_PATH = '/content/MSData/'
    JSON_PATH = '/content/ms_asl/'
    VIDEOS_PATH = '/content/video_new/'
    TrimmedVideos_PATH = VIDEOS_PATH + "TrimmedVideos/"

    # TrimVideoClip(VIDEOS_PATH)
    split_data()
# Out:
# Took 3622.7983288764954 seconds to execute
# Train:
# Test:
# ['big', 'bathroom', 'table', 'walk', 'here', 'white', 'black', 'yellow', 'orange', 'red', 'pink', 'blue', 'green', 'brown', 'no', 'doctor', 'nurse', 'teacher', 'grandmother', 'sign', 'night', 'happy', 'sad', 'hungry', 'tired', 'sick', 'like', 'want', 'know', 'how', 'computer', 'family', 'go', 'where', 'lost', 'drink', 'milk', 'milk', 'finish', 'green', 'woman', 'man', 'lost', 'forget', 'happy', 'sad', 'like', 'work', 'same', 'different', 'white', 'tired', 'forget', 'nice', 'student', 'work', 'school', 'doctor', 'nurse', 'family', 'grandmother', 'grandfather', 'cousin', 'water', 'boy', 'girl', 'sister', 'brother', 'cousin', 'mother', 'father', 'family', 'what', 'fish', 'play', 'computer', 'eat', 'yes', 'school', 'help', 'beautiful', 'big', 'deaf', 'happy', 'hearing', 'hello', 'tired', 'you', 'pencil', 'bad', 'sad', 'forget', 'finish', 'fine', 'sit', 'table', 'deaf', 'hearing', 'woman', 'girl', 'man', 'boy', 'teacher', 'learn', 'student', 'school', 'france', 'sign', 'yes', 'no', 'right', 'forget', 'know', 'sit', 'hello', 'want', 'happy', 'sad', 'tired', 'hurt', 'nice', 'family', 'thanks', 'good', 'teacher', 'student', 'nurse', 'sign', 'bird', 'grandfather', 'school', 'when', 'boy', 'sorry', 'table', 'sit', 'help', 'fine', 'what', 'need', 'must', 'now', 'blue', 'hungry', 'should', 'big', 'yes', 'nothing', 'eat', 'good', 'no', 'school', 'sick', 'sorry', 'understand', 'work', 'yes', 'eat', 'hungry', 'drink', 'doctor', 'nurse', 'tired', 'eat', 'fish', 'family', 'mother', 'father', 'sister', 'brother', 'happy', 'mother', 'grandmother', 'father', 'grandfather', 'now', 'finish', 'walk', 'you', 'who', 'where', 'learn', 'student', 'teacher', 'man', 'woman', 'girl', 'boy', 'mother', 'father', 'sister', 'no', 'know', 'deaf', 'hello', 'name', 'live', 'nice', 'live', 'again', 'help', 'milk', 'spring', 'book', 'again', 'bad', 'bathroom', 'big', 'boy', 'but', 'father', 'day', 'finish', 'friend', 'girl', 'go', 'good', 'happy', 'hello', 'here', 'how', 'hurt', 'know', 'like', 'mother', 'nice', 'night', 'no', 'now', 'please', 'sad', 'same', 'school', 'sorry', 'thank you', 'what', 'when', 'where', 'who', 'work', 'yes', 'you', 'sorry', 'bathroom', 'sit', 'yes', 'no', 'finish', 'sick', 'happy', 'hungry', 'sad', 'tired', 'good', 'bad', 'help', 'water', 'draw', 'write', 'play', 'teacher', 'student', 'sit', 'table', 'orange', 'hello', 'good', 'bad', 'right', 'yes', 'no', 'sign', 'forget', 'thank you', 'same', 'different', 'know', 'again', 'understand', 'student', 'teacher', 'name', 'nice', 'hearing', 'drink', 'play', 'sick', 'doctor', 'night', 'like', 'nice', 'work', 'finish', 'but', 'bird', 'father', 'pencil', 'learn', 'big', 'mother', 'english', 'like', 'lost', 'pink', 'sit', 'different', 'right', 'black', 'yellow', 'family', 'mother', 'father', 'sister', 'brother', 'cousin', 'friend', 'grandfather', 'grandmother', 'you', 'no', 'nothing', 'eat', 'chicken', 'water', 'milk', 'school', 'walk', 'yellow', 'yes', 'bird', 'table', 'sit', 'book', 'paper', 'pencil', 'spring', 'milk', 'eat', 'nothing', 'how', 'black', 'white', 'france', 'right', 'happy', 'sorry', 'like', 'orange', 'blue', 'understand', 'bathroom', 'water', 'please', 'thank you', 'sorry', 'understand', 'yes', 'no', 'help', 'red', 'learn', 'read', 'write', 'paper', 'book', 'fish', 'computer', 'lost', 'paper', 'red', 'yellow', 'blue', 'pink', 'brown', 'orange', 'green', 'white', 'black', 'hello', 'please', 'sorry', 'what', 'who', 'when', 'where', 'how', 'deaf', 'man', 'woman', 'boy', 'girl', 'book', 'sit', 'paper', 'dance', 'write', 'draw', 'again', 'right', 'same', 'different', 'sick', 'hungry', 'water', 'table', 'hearing', 'go', 'sit', 'live', 'walk', 'spring', 'lost', 'play', 'big', 'beautiful', 'finish', 'here', 'black', 'brown', 'green', 'orange', 'pink', 'red', 'white', 'yellow', 'paper', 'bored', 'sick', 'family', 'mother', 'father', 'grandfather', 'cousin', 'brother', 'sister', 'friend', 'nice', 'read', 'same', 'yes', 'tired', 'read', 'you', 'brown', 'live', 'forget', 'france', 'english',  ...
# Processed videos:
# 575, 415

# %%
len(os.listdir("/content/MSData/val_cropped/"))
# Out:
# 105

# %%
shutil.rmtree("/content/MSData")

# %% [markdown]
# /content/MSData//train/day/my4mxg6lXYQ.mp4
# my4mxg6lXYQ

# %%
def convert_to_frames(input_data_path, word_count, input_type):
    """
    Takes Raw training Input dataset and converts them from video to frames
    """
    # need to change image data for different conversions
    image_data = os.path.join( "MS_Data_Pictures/image_data_" + input_type)
    if (not exists(image_data)):
        os.makedirs(image_data)

    frame_count = 0

    input_dir = os.path.join(input_data_path, input_type)

    # Get all files with raw data for words, only keep how many you want
    gesture_list = os.listdir(input_dir)
    #gesture_list = gesture_list[:word_count]
    print(gesture_list)
    for gesture in gesture_list:
        gesture_path = os.path.join(input_dir, gesture)
        #print("gesture_path: ",gesture_path)

        # Create directory to store images
        frames = os.path.join(image_data, gesture)
        if(not os.path.exists(frames)):
            os.makedirs(frames)
        #print("frames", frames)

        videos = os.listdir(gesture_path)
        videos = [video for video in videos if(os.path.isfile(gesture_path + '/' +  video))]
        # print(videos)
        for video in videos:
            video_name = video[:-4] #removing .mp4 from the video name
            #print("video_name: ", video_name)
            vidcap = cv2.VideoCapture(gesture_path + '/' +  video)
            success,image = vidcap.read()
            frame_count = 0
            # if success:
            #   print("reading video sucessful")
            # else:
            #   print(success)
            while success:
              # image = cv2.cvtcolor(image,cv2.color_bgr2gray) # to convert image to grayscale
              cv2.imwrite(f"{image_data}/{gesture}/{video_name}_frame{frame_count}.jpg", image)     # save frame as jpeg file
              success,image = vidcap.read()
              # print('read a new frame: ', success)
              frame_count += 1

# %%
# convert_to_frames("MSData/",10,"test_cropped")

# %% [markdown]
# ## 1.5 Zip and store data

# %%
# !mkdir drive/MyDrive/SignLanguagev2/
# Out:
# mkdir: cannot create directory ‘drive/MyDrive/SignLanguagev2/’: File exists

# %%
# !zip -r drive/MyDrive/SignLanguagev2/MSData.zip /content/MSData

# %%
# !zip -r drive/MyDrive/SignLanguagev2/ValMSData.zip /content/MSData
# Out:
#   adding: content/MSData/ (stored 0%)
#   adding: content/MSData/val_cropped/ (stored 0%)
#   adding: content/MSData/val_cropped/like/ (stored 0%)
#   adding: content/MSData/val_cropped/like/cxXEULq9Jpc.mp4 (deflated 11%)
#   adding: content/MSData/val_cropped/like/CxTSVyM-ij0.mp4 (deflated 7%)
#   adding: content/MSData/val_cropped/like/EyWuC4JL4Tk.mp4 (deflated 8%)
#   adding: content/MSData/val_cropped/like/GmxS5HkNc3o.mp4 (deflated 3%)
#   adding: content/MSData/val_cropped/like/HUMEcnkvhJU&t.mp4 (deflated 13%)
#   adding: content/MSData/val_cropped/like/1bj72qXSy8c.mp4 (deflated 7%)
#   adding: content/MSData/val_cropped/like/0qeMFifNqC4.mp4 (deflated 24%)
#   adding: content/MSData/val_cropped/like/N4n5CDpyX3w.mp4 (deflated 19%)
#   adding: content/MSData/val_cropped/girl/ (stored 0%)
#   adding: content/MSData/val_cropped/girl/0bIF7jh6lnE.mp4 (deflated 1%)
#   adding: content/MSData/val_cropped/girl/KLD5f35qEDI&t.mp4 (deflated 11%)
#   adding: content/MSData/val_cropped/girl/FRQbKDZeRzM.mp4 (deflated 7%)
#   adding: content/MSData/val_cropped/girl/2VB3WN8adyM.mp4 (deflated 6%)
#   adding: content/MSData/val_cropped/girl/HUMEcnkvhJU&t.mp4 (deflated 6%)
#   adding: content/MSData/val_cropped/girl/BEKUHzwnVO8.mp4 (deflated 29%)
#   adding: content/MSData/val_cropped/girl/7m6N78E-5uE.mp4 (deflated 32%)
#   adding: content/MSData/val_cropped/family/ (stored 0%)
#   adding: content/MSData/val_cropped/family/7sZLZpm4n2E.mp4 (deflated 8%)
#   adding: content/MSData/val_cropped/family/fNBK5IuEIkk.mp4 (deflated 7%)
#   adding: content/MSData/val_cropped/family/1b2TXYk0jbM.mp4 (deflated 10%)
#   adding: content/MSData/val_cropped/family/JYF-AfMbUNw.mp4 (deflated 1%)
#   adding: content/MSData/val_cropped/family/7m6N78E-5uE.mp4 (deflated 29%)
#   adding: content/MSData/val_cropped/family/psspxdbtM3k.mp4 (deflated 6%)
#   adding: content/MSData/val_cropped/family/n7MQUHa0vr4&t.mp4 (deflated 9%)
#   adding: content/MSData/val_cropped/nothing/ (stored 0%)
#   adding: content/MSData/val_cropped/nothing/KLD5f35qEDI&t.mp4 (deflated 12%)
#   adding: content/MSData/val_cropped/nothing/zJHMuqY5wnY.mp4 (deflated 18%)
#   adding: content/MSData/val_cropped/nothing/FRQbKDZeRzM.mp4 (deflated 12%)
#   adding: content/MSData/val_cropped/nothing/JYF-AfMbUNw.mp4 (deflated 1%)
#   adding: content/MSData/val_cropped/nothing/dELt8wh_5nA&t.mp4 (deflated 9%)
#   adding: content/MSData/val_cropped/nothing/5sILDEiOcQ0.mp4 (deflated 11%)
#   adding: content/MSData/val_cropped/deaf/ (stored 0%)
#   adding: content/MSData/val_cropped/deaf/cxXEULq9Jpc.mp4 (deflated 13%)
#   adding: content/MSData/val_cropped/deaf/0bIF7jh6lnE.mp4 (deflated 2%)
#   adding: content/MSData/val_cropped/deaf/Qvn5RGyb0po.mp4 (deflated 18%)
#   adding: content/MSData/val_cropped/deaf/2VB3WN8adyM.mp4 (deflated 7%)
#   adding: content/MSData/val_cropped/deaf/BEKUHzwnVO8.mp4 (deflated 26%)
#   adding: content/MSData/val_cropped/deaf/kZuJalsv_z0.mp4 (deflated 18%)
#   adding: content/MSData/val_cropped/deaf/KGcYDLCx3bE.mp4 (deflated 1%)
#   adding: content/MSData/val_cropped/orange/ (stored 0%)
#   adding: content/MSData/val_cropped/orange/koMZVbqiXf4.mp4 (deflated 1%)
#   adding: content/MSData/val_cropped/orange/QBtof6T2N0Q.mp4 (deflated 0%)
#   adding: content/MSData/val_cropped/orange/hKogDJd0yc4.mp4 (deflated 15%)
#   adding: content/MSData/val_cropped/orange/QwxSYpnuATA.mp4 (deflated 7%)
#   adding: content/MSData/val_cropped/orange/2VB3WN8adyM.mp4 (deflated 5%)
#   adding: content/MSData/val_cropped/orange/He0k3ddd67A.mp4 (deflated 8%)
#   adding: content/MSData/val_cropped/orange/n7MQUHa0vr4&t.mp4 (deflated 10%)
#   adding: content/MSData/val_cropped/understand/ (stored 0%)
#   adding: content/MSData/val_cropped/understand/g59_3vr_NT0.mp4 (deflated 19%)
#   adding: content/MSData/val_cropped/understand/9bosgmeAAuo.mp4 (deflated 21%)
#   adding: content/MSData/val_cropped/understand/0v4Y9WGhES8.mp4 (deflated 14%)
#   adding: content/MSData/val_cropped/understand/qb7wnmYhgC8.mp4 (deflated 1%)
#   adding: content/MSData/val_cropped/understand/sQELZPmche8.mp4 (deflated 1%)
#   adding: content/MSData/val_cropped/sister/ (stored 0%)
#   adding: content/MSData/val_cropped/sister/JYF-AfMbUNw.mp4 (deflated 1%)
#   adding: content/MSData/val_cropped/sister/BEKUHzwnVO8.mp4 (deflated 16%)
#   adding: content/MSData/val_cropped/sister/7m6N78E-5uE.mp4 (deflated 28%)
#   adding: content/MSData/val_cropped/sister/psspxdbtM3k.mp4 (deflated 7%)
#   adding: content/MSData/val_cropped/sister/n7MQUHa0vr4&t.mp4 (deflated 5%)
#   adding: content/MSData/val_cropped/man/ (stored 0%)
#   adding: content/MSData/val_cropped/man/0bIF7jh6lnE.mp4 (deflated 1%)
#   adding: content/MSData/val_cropped/man/KLD5f35qEDI&t.mp4 (deflated 17%)
#   adding: content/MSData/val_cropped/man/2VB3WN8adyM.mp4 (deflated 6%)
#   adding: content/MSData/val_cropped/man/BEKUHzwnVO8.mp4 (deflated 25%)
#   adding: content/MSData/val_cropped/man/N4n5CDpyX3w.mp4 (deflated 20%)
#   adding: content/MSData/val_cropped/green/ (stored 0%)
#   adding: content/MSData/val_cropped/green/wiXtgEnJjMA.mp4 (deflated 1%)
#   adding: content/MSData/val_cropped/green/koMZVbqiXf4.mp4 (deflated 1%)
#   adding: content/MSData/val_cropped/green/hKogDJd0yc4.mp4 (deflated 15%)
#   adding: content/MSData/val_cropped/green/2VB3WN8adyM.mp4 (deflated 5%)
#   adding: content/MSData/val_cropped/green/n7MQUHa0vr4&t.mp4 (deflated 10%)
#   adding: content/MSData/val_cropped/drink/ (stored 0%)
#   adding: content/MSData/val_cropped/drink/KLD5f35qEDI&t.mp4 (deflated 10%)
#   adding: content/MSData/val_cropped/drink/1lifyGwZN7g.mp4 (deflated 2%)
#   adding: content/MSData/val_cropped/drink/eeHS78JyN70.mp4 (deflated 21%)
#   adding: content/MSData/val_cropped/drink/Nc7rSopCpI8.mp4 (deflated 25%)
#   adding: content/MSData/val_cropped/black/ (stored 0%)
#   adding: content/MSData/val_cropped/black/koMZVbqiXf4.mp4 (deflated 1%)
#   adding: content/MSData/val_cropped/black/2ofPs_uTel4.mp4 (deflated 2%)
#   adding: content/MSData/val_cropped/black/IAYDcpRyf1Q.mp4 (deflated 1%)
#   adding: content/MSData/val_cropped/black/FRQbKDZeRzM.mp4 (deflated 11%)
#   adding: content/MSData/val_cropped/black/2VB3WN8adyM.mp4 (deflated 5%)
#   adding: content/MSData/val_cropped/black/7yKNI0jlXMs.mp4 (deflated 0%)
#   adding: content/MSData/val_cropped/black/VcRx3U-HpTE.mp4 (deflated 10%)
#   adding: content/MSData/val_cropped/black/n7MQUHa0vr4&t.mp4 (deflated 8%)
#   adding: content/MSData/val_cropped/same/ (stored 0%)
#   adding: content/MSData/val_cropped/same/2VB3WN8adyM.mp4 (deflated 6%)
#   adding: content/MSData/val_cropped/same/q3AuBy_qiAA.mp4 (deflated 1%)
#   adding: content/MSData/val_cropped/same/9bosgmeAAuo.mp4 (deflated 15%)
#   adding: content/MSData/val_cropped/same/HUMEcnkvhJU&t.mp4 (deflated 11%)
#   adding: content/MSData/val_cropped/same/0v4Y9WGhES8.mp4 (deflated 14%)
#   adding: content/MSData/val_cropped/same/N4n5CDpyX3w.mp4 (deflated 23%)
#   adding: content/MSData/val_cropped/same/n7MQUHa0vr4&t.mp4 (deflated 16%)
#   adding: content/MSData/val_cropped/want/ (stored 0%)
#   adding: content/MSData/val_cropped/want/cxXEULq9Jpc.mp4 (deflated 13%)
#   adding: content/MSData/val_cropped/want/CxTSVyM-ij0.mp4 (deflated 9%)
#   adding: content/MSData/val_cropped/want/co7zdtkJW1E.mp4 (deflated 14%)
#   adding: content/MSData/val_cropped/go/ (stored 0%)
#   adding: content/MSData/val_cropped/go/J9kZS0VdY_A&t.mp4 (deflated 19%)
#   adding: content/MSData/val_cropped/go/1b2TXYk0jbM.mp4 (deflated 5%)
#   adding: content/MSData/val_cropped/go/GmxS5HkNc3o.mp4 (deflated 7%)
#   adding: content/MSData/val_cropped/go/HUMEcnkvhJU&t.mp4 (deflated 10%)
#   adding: content/MSData/val_cropped/go/UmcAkb54I4c.mp4 (deflated 6%)
#   adding: content/MSData/val_cropped/school/ (stored 0%)
#   adding: content/MSData/val_cropped/school/cxXEULq9Jpc.mp4 (deflated 13%)
#   adding: content/MSData/val_cropped/school/0bIF7jh6lnE.mp4 (deflated 1%)
#   adding: content/MSData/val_cropped/school/g59_3vr_NT0.mp4 (deflated 15%)
#   adding: content/MSData/val_cropped/school/86OOotf8Sxc.mp4 (deflated 3%)
#   adding: content/MSData/val_cropped/school/EFTKM2dMkBE.mp4 (deflated 7%)
#   adding: content/MSData/val_cropped/school/HUMEcnkvhJU&t.mp4 (deflated 9%)
#   adding: content/MSData/val_cropped/school/o8vR5ZtYFFs.mp4 (deflated 1%)
#   adding: content/MSData/val_cropped/school/ig7SKr3tvWc.mp4 (deflated 24%)
#   adding: content/MSData/val_cropped/hungry/ (stored 0%)
#   adding: content/MSData/val_cropped/hungry/KLD5f35qEDI&t.mp4 (deflated 9%)
#   adding: content/MSData/val_cropped/hungry/bX1eJjB3nyA.mp4 (deflated 1%)
#   adding: content/MSData/val_cropped/hungry/eeHS78JyN70.mp4 (deflated 27%)
#   adding: content/MSData/val_cropped/hungry/KsvdFnvMNAA.mp4 (deflated 1%)
#   adding: content/MSData/val_cropped/hungry/CxTSVyM-ij0.mp4 (deflated 7%)
#   adding: content/MSData/val_cropped/hungry/5sILDEiOcQ0.mp4 (deflated 7%)
#   adding: content/MSData/val_cropped/should/ (stored 0%)
#   adding: content/MSData/val_cropped/should/5sILDEiOcQ0.mp4 (deflated 7%)
#   adding: content/MSData/val_cropped/doctor/ (stored 0%)
#   adding: content/MSData/val_cropped/doctor/iR6M4P6XqB0.mp4 (deflated 5%)
#   adding: content/MSData/val_cropped/doctor/KLD5f35qEDI&t.mp4 (deflated 16%)
#   adding: content/MSData/val_cropped/doctor/eeHS78JyN70.mp4 (deflated 22%)
#   adding: content/MSData/val_cropped/doctor/2ofPs_uTel4.mp4 (deflated 2%)
#   adding: content/MSData/val_cropped/doctor/EFTKM2dMkBE.mp4 (deflated 16%)
#   adding: content/MSData/val_cropped/doctor/1bj72qXSy8c.mp4 (deflated 6%)
#   adding: content/MSData/val_cropped/computer/ (stored 0%)
#   adding: content/MSData/val_cropped/computer/KLD5f35qEDI&t.mp4 (deflated 11%)
#   adding: content/MSData/val_cropped/computer/H-tAzh-nuV8.mp4 (deflated 19%)
#   adding: content/MSData/val_cropped/computer/gVUwBsPOUjk.mp4 (deflated 21%)
#   adding: content/MSData/val_cropped/computer/KkIZgjMaWpg.mp4 (deflated 1%)
#   adding: content/MSData/val_cropped/good/ (stored 0%)
#   adding: content/MSData/val_cropped/good/bX1eJjB3nyA.mp4 (deflated 1%)
#   adding: content/MSData/val_cropped/good/hKogDJd0yc4.mp4 (deflated 23%)
#   adding: content/MSData/val_cropped/good/g59_3vr_NT0.mp4 (deflated 13%)
#   adding: content/MSData/val_cropped/good/FRQbKDZeRzM.mp4 (deflated 16%)
#   adding: content/MSData/val_cropped/good/9mxvzW7doks.mp4 (deflated 1%)
#   adding: content/MSData/val_cropped/good/rIlQQTN2b58.mp4 (deflated 10%)
#   adding: content/MSData/val_cropped/good/HUMEcnkvhJU&t.mp4 (deflated 4%)
#   adding: content/MSData/val_cropped/good/0v4Y9WGhES8.mp4 (deflated 18%)
#   adding: content/MSData/val_cropped/thanks/ (stored 0%)
#   adding: content/MSData/val_cropped/thanks/fNBK5IuEIkk.mp4 (deflated 1%)
#   adding: content/MSData/val_cropped/hurt/ (stored 0%)
#   adding: content/MSData/val_cropped/hurt/2ofPs_uTel4.mp4 (deflated 1%)
#   adding: content/MSData/val_cropped/hurt/HUMEcnkvhJU&t.mp4 (deflated 5%)
#   adding: content/MSData/val_cropped/hurt/R_G5zGVHxkU.mp4 (deflated 27%)
#   adding: content/MSData/val_cropped/where/ (stored 0%)
#   adding: content/MSData/val_cropped/where/cxXEULq9Jpc.mp4 (deflated 13%)
#   adding: content/MSData/val_cropped/where/1b2TXYk0jbM.mp4 (deflated 5%)
#   adding: content/MSData/val_cropped/where/2VB3WN8adyM.mp4 (deflated 6%)
#   adding: content/MSData/val_cropped/where/HUMEcnkvhJU&t.mp4 (deflated 12%)
#   adding: content/MSData/val_cropped/where/BEKUHzwnVO8.mp4 (deflated 22%)
#   adding: content/MSData/val_cropped/read/ (stored 0%)
#   adding: content/MSData/val_cropped/read/1dyyaQH7m_Y.mp4 (deflated 11%)
#   adding: content/MSData/val_cropped/read/afwqCG7GmrQ.mp4 (deflated 7%)
#   adding: content/MSData/val_cropped/read/n7MQUHa0vr4&t.mp4 (deflated 9%)
#   adding: content/MSData/val_cropped/read/Nx5yZfVGuX8.mp4 (deflated 21%)
#   adding: content/MSData/val_cropped/student/ (stored 0%)
#   adding: content/MSData/val_cropped/student/0bIF7jh6lnE.mp4 (deflated 2%)
#   adding: content/MSData/val_cropped/student/bX1eJjB3nyA.mp4 (deflated 1%)
#   adding: content/MSData/val_cropped/student/EFTKM2dMkBE.mp4 (deflated 11%)
#   adding: content/MSData/val_cropped/student/IeH7XYbo0yg.mp4 (deflated 13%)
#   adding: content/MSData/val_cropped/student/BEKUHzwnVO8.mp4 (deflated 29%)
#   adding: content/MSData/val_cropped/student/0v4Y9WGhES8.mp4 (deflated 8%)
#   adding: content/MSData/val_cropped/must/ (stored 0%)
#   adding: content/MSData/val_cropped/must/_LGqHR3FhL8.mp4 (deflated 17%)
#   adding: content/MSData/val_cropped/grandmother/ (stored 0%)
#   adding: content/MSData/val_cropped/grandmother/7sZLZpm4n2E.mp4 (deflated 6%)
#   adding: content/MSData/val_cropped/grandmother/dtSmDTn3zkk.mp4 (deflated 12%)
#   adding: content/MSData/val_cropped/grandmother/Z8KGV-41MFQ.mp4 (deflated 3%)
#   adding: content/MSData/val_cropped/grandmother/JYF-AfMbUNw.mp4 (deflated 1%)
#   adding: content/MSData/val_cropped/walk/ (stored 0%)
#   adding: content/MSData/val_cropped/walk/koMZVbqiXf4.mp4 (deflated 1%)
#   adding: content/MSData/val_cropped/walk/XdA0TlfPB48.mp4 (deflated 28%)
#   adding: content/MSData/val_cropped/walk/J9kZS0VdY_A&t.mp4 (deflated 13%)
#   adding: content/MSData/val_cropped/walk/sxeWeiCoM7k.mp4 (deflated 3%)
#   adding: content/MSData/val_cropped/sad/ (stored 0%)
#   adding: content/MSData/val_cropped/sad/cxXEULq9Jpc.mp4 (deflated 10%)
#   adding: content/MSData/val_cropped/sad/bX1eJjB3nyA.mp4 (deflated 1%)
#   adding: content/MSData/val_cropped/sad/wLfH8VE_Vyo.mp4 (deflated 1%)
#   adding: content/MSData/val_cropped/sad/CxTSVyM-ij0.mp4 (deflated 11%)
#   adding: content/MSData/val_cropped/sad/rIlQQTN2b58.mp4 (deflated 12%)
#   adding: content/MSData/val_cropped/sad/HUMEcnkvhJU&t.mp4 (deflated 10%)
#   adding: content/MSData/val_cropped/sad/R_G5zGVHxkU.mp4 (deflated 25%)
#   adding: content/MSData/val_cropped/sad/N4n5CDpyX3w.mp4 (deflated 21%)
#   adding: content/MSData/val_cropped/brown/ (stored 0%)
#   adding: content/MSData/val_cropped/brown/koMZVbqiXf4.mp4 (deflated 1%)
#   adding: content/MSData/val_cropped/brown/hKogDJd0yc4.mp4 (deflated 20%)
#   adding: content/MSData/val_cropped/brown/2VB3WN8adyM.mp4 (deflated 5%)
#   adding: content/MSData/val_cropped/brown/n7MQUHa0vr4&t.mp4 (deflated 11%)
#   adding: content/MSData/val_cropped/brown/jR4eoFIkTHI.mp4 (deflated 1%)
#   adding: content/MSData/val_cropped/brother/ (stored 0%)
#   adding: content/MSData/val_cropped/brother/JYF-AfMbUNw.mp4 (deflated 1%)
#   adding: content/MSData/val_cropped/brother/7m6N78E-5uE.mp4 (deflated 30%)
#   adding: content/MSData/val_cropped/brother/psspxdbtM3k.mp4 (deflated 8%)
#   adding: content/MSData/val_cropped/brother/n7MQUHa0vr4&t.mp4 (deflated 9%)
#   adding: content/MSData/val_cropped/table/ (stored 0%)
#   adding: content/MSData/val_cropped/table/_LGqHR3FhL8.mp4 (deflated 20%)
#   adding: content/MSData/val_cropped/table/KLD5f35qEDI&t.mp4 (deflated 9%)
#   adding: content/MSData/val_cropped/table/nhEw0JSb-XQ.mp4 (deflated 1%)
#   adding: content/MSData/val_cropped/table/v_SV_07Gcfk.mp4 (deflated 10%)
#   adding: content/MSData/val_cropped/table/UjiCWH8PSvM.mp4 (deflated 11%)
#   adding: content/MSData/val_cropped/table/dELt8wh_5nA&t.mp4 (deflated 8%)
#   adding: content/MSData/val_cropped/table/7wuZuUIg114.mp4 (deflated 2%)
#   adding: content/MSData/val_cropped/table/f7tZegTJCWo.mp4 (deflated 14%)
#   adding: content/MSData/val_cropped/pencil/ (stored 0%)
#   adding: content/MSData/val_cropped/pencil/KLD5f35qEDI&t.mp4 (deflated 12%)
#   adding: content/MSData/val_cropped/pencil/UjiCWH8PSvM.mp4 (deflated 8%)
#   adding: content/MSData/val_cropped/pencil/fdNKKn0RS1g.mp4 (deflated 4%)
#   adding: content/MSData/val_cropped/pencil/bSQ9f3epmxQ.mp4 (deflated 5%)
#   adding: content/MSData/val_cropped/eat/ (stored 0%)
#   adding: content/MSData/val_cropped/eat/KLD5f35qEDI&t.mp4 (deflated 8%)
#   adding: content/MSData/val_cropped/eat/eeHS78JyN70.mp4 (deflated 14%)
#   adding: content/MSData/val_cropped/eat/XleDZhobVno.mp4 (deflated 1%)
#   adding: content/MSData/val_cropped/eat/g59_3vr_NT0.mp4 (deflated 16%)
#   adding: content/MSData/val_cropped/eat/lsjFBdE3X7M.mp4 (deflated 26%)
#   adding: content/MSData/val_cropped/eat/GmxS5HkNc3o.mp4 (deflated 5%)
#   adding: content/MSData/val_cropped/eat/CmKYKBQuHf4.mp4 (deflated 19%)
#   adding: content/MSData/val_cropped/eat/Qwdfx2_vzwc.mp4 (deflated 4%)
#   adding: content/MSData/val_cropped/again/ (stored 0%)
#   adding: content/MSData/val_cropped/again/cxXEULq9Jpc.mp4 (deflated 16%)
#   adding: content/MSData/val_cropped/again/n0PdKty8WRA.mp4 (deflated 5%)
#   adding: content/MSData/val_cropped/again/2VB3WN8adyM.mp4 (deflated 5%)
#   adding: content/MSData/val_cropped/again/9bosgmeAAuo.mp4 (deflated 11%)
#   adding: content/MSData/val_cropped/again/HUMEcnkvhJU&t.mp4 (deflated 5%)
#   adding: content/MSData/val_cropped/again/0v4Y9WGhES8.mp4 (deflated 15%)
#   adding: content/MSData/val_cropped/name/ (stored 0%)
#   adding: content/MSData/val_cropped/name/9bosgmeAAuo.mp4 (deflated 25%)
#   adding: content/MSData/val_cropped/name/BEKUHzwnVO8.mp4 (deflated 14%)
#   adding: content/MSData/val_cropped/name/0v4Y9WGhES8.mp4 (deflated 12%)
#   adding: content/MSData/val_cropped/right/ (stored 0%)
#   adding: content/MSData/val_cropped/right/0bIF7jh6lnE.mp4 (deflated 1%)
#   adding: content/MSData/val_cropped/right/hKogDJd0yc4.mp4 (deflated 9%)
#   adding: content/MSData/val_cropped/right/LHgwhGqtGJI.mp4 (deflated 1%)
#   adding: content/MSData/val_cropped/right/x0q-NTYinOY.mp4 (deflated 14%)
#   adding: content/MSData/val_cropped/right/2VB3WN8adyM.mp4 (deflated 5%)
#   adding: content/MSData/val_cropped/right/0v4Y9WGhES8.mp4 (deflated 10%)
#   adding: content/MSData/val_cropped/france/ (stored 0%)
#   adding: content/MSData/val_cropped/france/0bIF7jh6lnE.mp4 (deflated 2%)
#   adding: content/MSData/val_cropped/france/W4W1TdB7zkU.mp4 (deflated 4%)
#   adding: content/MSData/val_cropped/france/FWDwbVrTZTM.mp4 (deflated 18%)
#   adding: content/MSData/val_cropped/nurse/ (stored 0%)
#   adding: content/MSData/val_cropped/nurse/iR6M4P6XqB0.mp4 (deflated 4%)
#   adding: content/MSData/val_cropped/nurse/KLD5f35qEDI&t.mp4 (deflated 10%)
#   adding: content/MSData/val_cropped/nurse/eeHS78JyN70.mp4 (deflated 19%)
#   adding: content/MSData/val_cropped/nurse/EFTKM2dMkBE.mp4 (deflated 9%)
#   adding: content/MSData/val_cropped/nurse/IeH7XYbo0yg.mp4 (deflated 7%)
#   adding: content/MSData/val_cropped/bathroom/ (stored 0%)
#   adding: content/MSData/val_cropped/bathroom/KLD5f35qEDI&t.mp4 (deflated 4%)
#   adding: content/MSData/val_cropped/bathroom/bX1eJjB3nyA.mp4 (deflated 1%)
#   adding: content/MSData/val_cropped/bathroom/1dyyaQH7m_Y.mp4 (deflated 8%)
#   adding: content/MSData/val_cropped/bathroom/GmxS5HkNc3o.mp4 (deflated 5%)
#   adding: content/MSData/val_cropped/bathroom/HUMEcnkvhJU&t.mp4 (deflated 12%)
#   adding: content/MSData/val_cropped/bathroom/1JKqWk5UeQY.mp4 (deflated 2%)
#   adding: content/MSData/val_cropped/bathroom/sQELZPmche8.mp4 (deflated 2%)
#   adding: content/MSData/val_cropped/boy/ (stored 0%)
#   adding: content/MSData/val_cropped/boy/0bIF7jh6lnE.mp4 (deflated 2%)
#   adding: content/MSData/val_cropped/boy/KLD5f35qEDI&t.mp4 (deflated 11%)
#   adding: content/MSData/val_cropped/boy/FRQbKDZeRzM.mp4 (deflated 9%)
#   adding: content/MSData/val_cropped/boy/2VB3WN8adyM.mp4 (deflated 7%)
#   adding: content/MSData/val_cropped/boy/HUMEcnkvhJU&t.mp4 (deflated 8%)
#   adding: content/MSData/val_cropped/boy/BEKUHzwnVO8.mp4 (deflated 35%)
#   adding: content/MSData/val_cropped/boy/Fc0mGYlkQHg.mp4 (deflated 2%)
#   adding: content/MSData/val_cropped/boy/7m6N78E-5uE.mp4 (deflated 26%)
#   adding: content/MSData/val_cropped/nice/ (stored 0%)
#   adding: content/MSData/val_cropped/nice/FRQbKDZeRzM.mp4 (deflated 9%)
#   adding: content/MSData/val_cropped/nice/PBDUwwE9BFM&t.mp4 (deflated 1%)
#   adding: content/MSData/val_cropped/nice/dELt8wh_5nA&t.mp4 (deflated 4%)
#   adding: content/MSData/val_cropped/nice/HUMEcnkvhJU&t.mp4 (deflated 6%)
#   adding: content/MSData/val_cropped/nice/BEKUHzwnVO8.mp4 (deflated 20%)
#   adding: content/MSData/val_cropped/nice/R_G5zGVHxkU.mp4 (deflated 28%)
#   adding: content/MSData/val_cropped/nice/CYLvY25yI9c.mp4 (deflated 1%)
#   adding: content/MSData/val_cropped/nice/1bj72qXSy8c.mp4 (deflated 7%)
#   adding: content/MSData/val_cropped/nice/0v4Y9WGhES8.mp4 (deflated 17%)
#   adding: content/MSData/val_cropped/nice/n7MQUHa0vr4&t.mp4 (deflated 8%)
#   adding: content/MSData/val_cropped/fish/ (stored 0%)
#   adding: content/MSData/val_cropped/fish/KLD5f35qEDI&t.mp4 (deflated 11%)
#   adding: content/MSData/val_cropped/fish/ws12ZoG4qAU.mp4 (deflated 5%)
#   adding: content/MSData/val_cropped/fish/gVUwBsPOUjk.mp4 (deflated 20%)
#   adding: content/MSData/val_cropped/fish/rIlQQTN2b58.mp4 (deflated 6%)
#   adding: content/MSData/val_cropped/fish/kvJR02Idm-U.mp4 (deflated 1%)
#   adding: content/MSData/val_cropped/fish/He0k3ddd67A.mp4 (deflated 6%)
#   adding: content/MSData/val_cropped/please/ (stored 0%)
#   adding: content/MSData/val_cropped/please/cxXEULq9Jpc.mp4 (deflated 14%)
#   adding: content/MSData/val_cropped/please/2VB3WN8adyM.mp4 (deflated 6%)
#   adding: content/MSData/val_cropped/please/HUMEcnkvhJU&t.mp4 (deflated 5%)
#   adding: content/MSData/val_cropped/please/sQELZPmche8.mp4 (deflated 2%)
#   adding: content/MSData/val_cropped/teacher/ (stored 0%)
#   adding: content/MSData/val_cropped/teacher/iR6M4P6XqB0.mp4 (deflated 6%)
#   adding: content/MSData/val_cropped/teacher/0bIF7jh6lnE.mp4 (deflated 2%)
#   adding: content/MSData/val_cropped/teacher/KLD5f35qEDI&t.mp4 (deflated 9%)
#   adding: content/MSData/val_cropped/teacher/bX1eJjB3nyA.mp4 (deflated 1%)
#   adding: content/MSData/val_cropped/teacher/IeH7XYbo0yg.mp4 (deflated 12%)
#   adding: content/MSData/val_cropped/teacher/BEKUHzwnVO8.mp4 (deflated 28%)
#   adding: content/MSData/val_cropped/teacher/0v4Y9WGhES8.mp4 (deflated 13%)
#   adding: content/MSData/val_cropped/how/ (stored 0%)
#   adding: content/MSData/val_cropped/how/cxXEULq9Jpc.mp4 (deflated 9%)
#   adding: content/MSData/val_cropped/how/T-TyepUFxlI.mp4 (deflated 1%)
#   adding: content/MSData/val_cropped/how/2VB3WN8adyM.mp4 (deflated 6%)
#   adding: content/MSData/val_cropped/how/CxTSVyM-ij0.mp4 (deflated 19%)
#   adding: content/MSData/val_cropped/how/HUMEcnkvhJU&t.mp4 (deflated 6%)
#   adding: content/MSData/val_cropped/help/ (stored 0%)
#   adding: content/MSData/val_cropped/help/7OhTbCXAZQs.mp4 (deflated 2%)
#   adding: content/MSData/val_cropped/help/_LGqHR3FhL8.mp4 (deflated 13%)
#   adding: content/MSData/val_cropped/help/bX1eJjB3nyA.mp4 (deflated 1%)
#   adding: content/MSData/val_cropped/help/n0PdKty8WRA.mp4 (deflated 5%)
#   adding: content/MSData/val_cropped/help/GmxS5HkNc3o.mp4 (deflated 4%)
#   adding: content/MSData/val_cropped/help/sQELZPmche8.mp4 (deflated 1%)
#   adding: content/MSData/val_cropped/night/ (stored 0%)
#   adding: content/MSData/val_cropped/night/KLD5f35qEDI&t.mp4 (deflated 13%)
#   adding: content/MSData/val_cropped/night/CxTSVyM-ij0.mp4 (deflated 18%)
#   adding: content/MSData/val_cropped/night/HUMEcnkvhJU&t.mp4 (deflated 6%)
#   adding: content/MSData/val_cropped/night/1bj72qXSy8c.mp4 (deflated 9%)
#   adding: content/MSData/val_cropped/you/ (stored 0%)
#   adding: content/MSData/val_cropped/you/cxXEULq9Jpc.mp4 (deflated 10%)
#   adding: content/MSData/val_cropped/you/JYF-AfMbUNw.mp4 (deflated 1%)
#   adding: content/MSData/val_cropped/you/HUMEcnkvhJU&t.mp4 (deflated 12%)
#   adding: content/MSData/val_cropped/you/vEti7bfjCKk.mp4 (deflated 7%)
#   adding: content/MSData/val_cropped/you/BEKUHzwnVO8.mp4 (deflated 25%)
#   adding: content/MSData/val_cropped/you/kZuJalsv_z0.mp4 (deflated 22%)
#   adding: content/MSData/val_cropped/now/ (stored 0%)
#   adding: content/MSData/val_cropped/now/_LGqHR3FhL8.mp4 (deflated 23%)
#   adding: content/MSData/val_cropped/now/dtSmDTn3zkk.mp4 (deflated 15%)
#   adding: content/MSData/val_cropped/now/HUMEcnkvhJU&t.mp4 (deflated 4%)
#   adding: content/MSData/val_cropped/now/vmGh2IPdSRU.mp4 (deflated 22%)
#   adding: content/MSData/val_cropped/blue/ (stored 0%)
#   adding: content/MSData/val_cropped/blue/koMZVbqiXf4.mp4 (deflated 1%)
#   adding: content/MSData/val_cropped/blue/J_3nGXxrXpY.mp4 (deflated 4%)
#   adding: content/MSData/val_cropped/blue/Ber0gyYyBos.mp4 (deflated 1%)
#   adding: content/MSData/val_cropped/blue/2VB3WN8adyM.mp4 (deflated 5%)
#   adding: content/MSData/val_cropped/grandfather/ (stored 0%)
#   adding: content/MSData/val_cropped/grandfather/7sZLZpm4n2E.mp4 (deflated 8%)
#   adding: content/MSData/val_cropped/grandfather/dtSmDTn3zkk.mp4 (deflated 20%)
#   adding: content/MSData/val_cropped/grandfather/Z0oNgus1lzA.mp4 (deflated 5%)
#   adding: content/MSData/val_cropped/grandfather/JYF-AfMbUNw.mp4 (deflated 1%)
#   adding: content/MSData/val_cropped/grandfather/n7MQUHa0vr4&t.mp4 (deflated 10%)
#   adding: content/MSData/val_cropped/sorry/ (stored 0%)
#   adding: content/MSData/val_cropped/sorry/cxXEULq9Jpc.mp4 (deflated 11%)
#   adding: content/MSData/val_cropped/sorry/_LGqHR3FhL8.mp4 (deflated 26%)
#   adding: content/MSData/val_cropped/sorry/g59_3vr_NT0.mp4 (deflated 12%)
#   adding: content/MSData/val_cropped/sorry/Xq3QAqQXpTM.mp4 (deflated 1%)
#   adding: content/MSData/val_cropped/sorry/2VB3WN8adyM.mp4 (deflated 6%)
#   adding: content/MSData/val_cropped/sorry/M1CrNP2izNg.mp4 (deflated 1%)
#   adding: content/MSData/val_cropped/sorry/HUMEcnkvhJU&t.mp4 (deflated 12%)
#   adding: content/MSData/val_cropped/sorry/DGWErPoCHqw.mp4 (deflated 2%)
#   adding: content/MSData/val_cropped/sorry/sQELZPmche8.mp4 (deflated 3%)
#   adding: content/MSData/val_cropped/red/ (stored 0%)
#   adding: content/MSData/val_cropped/red/koMZVbqiXf4.mp4 (deflated 1%)
#   adding: content/MSData/val_cropped/red/hKogDJd0yc4.mp4 (deflated 15%)
#   adding: content/MSData/val_cropped/red/Y3MhO89mFdE.mp4 (deflated 1%)
#   adding: content/MSData/val_cropped/red/2VB3WN8adyM.mp4 (deflated 5%)
#   adding: content/MSData/val_cropped/red/n7MQUHa0vr4&t.mp4 (deflated 9%)
#   adding: content/MSData/val_cropped/red/p-zYYFu5PQA.mp4 (deflated 1%)
#   adding: content/MSData/val_cropped/friend/ (stored 0%)
#   adding: content/MSData/val_cropped/friend/JYF-AfMbUNw.mp4 (deflated 1%)
#   adding: content/MSData/val_cropped/friend/HUMEcnkvhJU&t.mp4 (deflated 8%)
#   adding: content/MSData/val_cropped/friend/n7MQUHa0vr4&t.mp4 (deflated 6%)
#   adding: content/MSData/val_cropped/happy/ (stored 0%)
#   adding: content/MSData/val_cropped/happy/cxXEULq9Jpc.mp4 (deflated 14%)
#   adding: content/MSData/val_cropped/happy/bX1eJjB3nyA.mp4 (deflated 1%)
#   adding: content/MSData/val_cropped/happy/Xq3QAqQXpTM.mp4 (deflated 2%)
#   adding: content/MSData/val_cropped/happy/7bWO4SJ0sv4.mp4 (deflated 1%)
#   adding: content/MSData/val_cropped/happy/CxTSVyM-ij0.mp4 (deflated 10%)
#   adding: content/MSData/val_cropped/happy/rIlQQTN2b58.mp4 (deflated 12%)
#   adding: content/MSData/val_cropped/happy/HUMEcnkvhJU&t.mp4 (deflated 5%)
#   adding: content/MSData/val_cropped/happy/R_G5zGVHxkU.mp4 (deflated 29%)
#   adding: content/MSData/val_cropped/happy/N4n5CDpyX3w.mp4 (deflated 22%)
#   adding: content/MSData/val_cropped/happy/kZuJalsv_z0.mp4 (deflated 18%)
#   adding: content/MSData/val_cropped/cousin/ (stored 0%)
#   adding: content/MSData/val_cropped/cousin/7sZLZpm4n2E.mp4 (deflated 4%)
#   adding: content/MSData/val_cropped/cousin/JYF-AfMbUNw.mp4 (deflated 1%)
#   adding: content/MSData/val_cropped/cousin/7m6N78E-5uE.mp4 (deflated 32%)
#   adding: content/MSData/val_cropped/cousin/n7MQUHa0vr4&t.mp4 (deflated 10%)
#   adding: content/MSData/val_cropped/different/ (stored 0%)
#   adding: content/MSData/val_cropped/different/x0q-NTYinOY.mp4 (deflated 28%)
#   adding: content/MSData/val_cropped/different/2VB3WN8adyM.mp4 (deflated 7%)
#   adding: content/MSData/val_cropped/different/0v4Y9WGhES8.mp4 (deflated 13%)
#   adding: content/MSData/val_cropped/different/N4n5CDpyX3w.mp4 (deflated 22%)
#   adding: content/MSData/val_cropped/sign/ (stored 0%)
#   adding: content/MSData/val_cropped/sign/chUNuSYnCck.mp4 (deflated 1%)
#   adding: content/MSData/val_cropped/sign/0bIF7jh6lnE.mp4 (deflated 5%)
#   adding: content/MSData/val_cropped/sign/0v4Y9WGhES8.mp4 (deflated 14%)
#   adding: content/MSData/val_cropped/sign/tl_1gdc166A.mp4 (deflated 26%)
#   adding: content/MSData/val_cropped/who/ (stored 0%)
#   adding: content/MSData/val_cropped/who/cxXEULq9Jpc.mp4 (deflated 16%)
#   adding: content/MSData/val_cropped/who/2VB3WN8adyM.mp4 (deflated 5%)
#   adding: content/MSData/val_cropped/who/HUMEcnkvhJU&t.mp4 (deflated 7%)
#   adding: content/MSData/val_cropped/who/BEKUHzwnVO8.mp4 (deflated 10%)
#   adding: content/MSData/val_cropped/dance/ (stored 0%)
#   adding: content/MSData/val_cropped/dance/2VB3WN8adyM.mp4 (deflated 5%)
#   adding: content/MSData/val_cropped/dance/G6pN8BFQYDI.mp4 (deflated 27%)
#   adding: content/MSData/val_cropped/milk/ (stored 0%)
#   adding: content/MSData/val_cropped/milk/n0PdKty8WRA.mp4 (deflated 6%)
#   adding: content/MSData/val_cropped/milk/JD_CiyDFnkM.mp4 (deflated 17%)
#   adding: content/MSData/val_cropped/milk/AW2kJeqxKds.mp4 (deflated 2%)
#   adding: content/MSData/val_cropped/milk/CmKYKBQuHf4.mp4 (deflated 14%)
#   adding: content/MSData/val_cropped/milk/He0k3ddd67A.mp4 (deflated 10%)
#   adding: content/MSData/val_cropped/milk/_wijo648v0g.mp4 (deflated 6%)
#   adding: content/MSData/val_cropped/milk/creSIQ3owuo.mp4 (deflated 1%)
#   adding: content/MSData/val_cropped/no/ (stored 0%)
#   adding: content/MSData/val_cropped/no/0bIF7jh6lnE.mp4 (deflated 1%)
#   adding: content/MSData/val_cropped/no/bX1eJjB3nyA.mp4 (deflated 1%)
#   adding: content/MSData/val_cropped/no/g59_3vr_NT0.mp4 (deflated 18%)
#   adding: content/MSData/val_cropped/no/URb48i4X52U.mp4 (deflated 2%)
#   adding: content/MSData/val_cropped/no/JYF-AfMbUNw.mp4 (deflated 1%)
#   adding: content/MSData/val_cropped/no/HUMEcnkvhJU&t.mp4 (deflated 16%)
#   adding: content/MSData/val_cropped/no/BEKUHzwnVO8.mp4 (deflated 17%)
#   adding: content/MSData/val_cropped/no/0v4Y9WGhES8.mp4 (deflated 19%)
#   adding: content/MSData/val_cropped/no/sQELZPmche8.mp4 (deflated 3%)
#   adding: content/MSData/val_cropped/no/0HvgswZfDGI.mp4 (deflated 1%)
#   adding: content/MSData/val_cropped/but/ (stored 0%)
#   adding: content/MSData/val_cropped/but/4h3wQWXM0PM.mp4 (deflated 1%)
#   adding: content/MSData/val_cropped/but/HUMEcnkvhJU&t.mp4 (deflated 6%)
#   adding: content/MSData/val_cropped/learn/ (stored 0%)
#   adding: content/MSData/val_cropped/learn/cxXEULq9Jpc.mp4 (deflated 11%)
#   adding: content/MSData/val_cropped/learn/0bIF7jh6lnE.mp4 (deflated 1%)
#   adding: content/MSData/val_cropped/learn/afwqCG7GmrQ.mp4 (deflated 8%)
#   adding: content/MSData/val_cropped/learn/9bosgmeAAuo.mp4 (deflated 22%)
#   adding: content/MSData/val_cropped/learn/BEKUHzwnVO8.mp4 (deflated 28%)
#   adding: content/MSData/val_cropped/learn/FwrpfdqyEDo.mp4 (deflated 20%)
#   adding: content/MSData/val_cropped/bored/ (stored 0%)
#   adding: content/MSData/val_cropped/bored/n7MQUHa0vr4&t.mp4 (deflated 10%)
#   adding: content/MSData/val_cropped/play/ (stored 0%)
#   adding: content/MSData/val_cropped/play/bX1eJjB3nyA.mp4 (deflated 2%)
#   adding: content/MSData/val_cropped/play/M80w0mda7zM.mp4 (deflated 25%)
#   adding: content/MSData/val_cropped/play/J9kZS0VdY_A&t.mp4 (deflated 11%)
#   adding: content/MSData/val_cropped/play/ws12ZoG4qAU.mp4 (deflated 5%)
#   adding: content/MSData/val_cropped/play/1bj72qXSy8c.mp4 (deflated 10%)
#   adding: content/MSData/val_cropped/write/ (stored 0%)
#   adding: content/MSData/val_cropped/write/KLD5f35qEDI&t.mp4 (deflated 13%)
#   adding: content/MSData/val_cropped/write/bX1eJjB3nyA.mp4 (deflated 2%)
#   adding: content/MSData/val_cropped/write/afwqCG7GmrQ.mp4 (deflated 6%)
#   adding: content/MSData/val_cropped/write/2VB3WN8adyM.mp4 (deflated 6%)
#   adding: content/MSData/val_cropped/lost/ (stored 0%)
#   adding: content/MSData/val_cropped/lost/-IEFUtDrWCg.mp4 (deflated 1%)
#   adding: content/MSData/val_cropped/lost/J9kZS0VdY_A&t.mp4 (deflated 9%)
#   adding: content/MSData/val_cropped/lost/fii2boOPUnY.mp4 (deflated 1%)
#   adding: content/MSData/val_cropped/lost/dELt8wh_5nA&t.mp4 (deflated 12%)
#   adding: content/MSData/val_cropped/lost/N4n5CDpyX3w.mp4 (deflated 17%)
#   adding: content/MSData/val_cropped/lost/6cqY0BbfE80.mp4 (deflated 22%)
#   adding: content/MSData/val_cropped/mother/ (stored 0%)
#   adding: content/MSData/val_cropped/mother/dtSmDTn3zkk.mp4 (deflated 23%)
#   adding: content/MSData/val_cropped/mother/c5a0wBqihes.mp4 (deflated 1%)
#   adding: content/MSData/val_cropped/mother/JYF-AfMbUNw.mp4 (deflated 1%)
#   adding: content/MSData/val_cropped/mother/HUMEcnkvhJU&t.mp4 (deflated 9%)
#   adding: content/MSData/val_cropped/mother/BEKUHzwnVO8.mp4 (deflated 27%)
#   adding: content/MSData/val_cropped/mother/7m6N78E-5uE.mp4 (deflated 34%)
#   adding: content/MSData/val_cropped/mother/psspxdbtM3k.mp4 (deflated 4%)
#   adding: content/MSData/val_cropped/mother/n7MQUHa0vr4&t.mp4 (deflated 17%)
#   adding: content/MSData/val_cropped/know/ (stored 0%)
#   adding: content/MSData/val_cropped/know/cxXEULq9Jpc.mp4 (deflated 19%)
#   adding: content/MSData/val_cropped/know/0bIF7jh6lnE.mp4 (deflated 2%)
#   adding: content/MSData/val_cropped/know/CxTSVyM-ij0.mp4 (deflated 4%)
#   adding: content/MSData/val_cropped/know/HUMEcnkvhJU&t.mp4 (deflated 9%)
#   adding: content/MSData/val_cropped/know/BEKUHzwnVO8.mp4 (deflated 21%)
#   adding: content/MSData/val_cropped/know/0v4Y9WGhES8.mp4 (deflated 13%)
#   adding: content/MSData/val_cropped/finish/ (stored 0%)
#   adding: content/MSData/val_cropped/finish/bX1eJjB3nyA.mp4 (deflated 1%)
#   adding: content/MSData/val_cropped/finish/dtSmDTn3zkk.mp4 (deflated 18%)
#   adding: content/MSData/val_cropped/finish/JDc62QM6-GU.mp4 (deflated 28%)
#   adding: content/MSData/val_cropped/finish/J9kZS0VdY_A&t.mp4 (deflated 15%)
#   adding: content/MSData/val_cropped/finish/GmxS5HkNc3o.mp4 (deflated 6%)
#   adding: content/MSData/val_cropped/finish/HUMEcnkvhJU&t.mp4 (deflated 7%)
#   adding: content/MSData/val_cropped/finish/1bj72qXSy8c.mp4 (deflated 10%)
#   adding: content/MSData/val_cropped/finish/f7tZegTJCWo.mp4 (deflated 11%)
#   adding: content/MSData/val_cropped/beautiful/ (stored 0%)
#   adding: content/MSData/val_cropped/beautiful/hKogDJd0yc4.mp4 (deflated 26%)
#   adding: content/MSData/val_cropped/beautiful/J9kZS0VdY_A&t.mp4 (deflated 6%)
#   adding: content/MSData/val_cropped/beautiful/qE0EsE4dTj8.mp4 (deflated 0%)
#   adding: content/MSData/val_cropped/beautiful/rIlQQTN2b58.mp4 (deflated 10%)
#   adding: content/MSData/val_cropped/beautiful/kZuJalsv_z0.mp4 (deflated 20%)
#   adding: content/MSData/val_cropped/here/ (stored 0%)
#   adding: content/MSData/val_cropped/here/koMZVbqiXf4.mp4 (deflated 1%)
#   adding: content/MSData/val_cropped/here/KLD5f35qEDI&t.mp4 (deflated 14%)
#   adding: content/MSData/val_cropped/here/9bosgmeAAuo.mp4 (deflated 14%)
#   adding: content/MSData/val_cropped/here/HUMEcnkvhJU&t.mp4 (deflated 5%)
#   adding: content/MSData/val_cropped/here/JBIstMmmHxI.mp4 (deflated 20%)
#   adding: content/MSData/val_cropped/sick/ (stored 0%)
#   adding: content/MSData/val_cropped/sick/bX1eJjB3nyA.mp4 (deflated 1%)
#   adding: content/MSData/val_cropped/sick/g59_3vr_NT0.mp4 (deflated 19%)
#   adding: content/MSData/val_cropped/sick/CxTSVyM-ij0.mp4 (deflated 10%)
#   adding: content/MSData/val_cropped/sick/bS9icDOS5g4.mp4 (deflated 20%)
#   adding: content/MSData/val_cropped/sick/1bj72qXSy8c.mp4 (deflated 10%)
#   adding: content/MSData/val_cropped/sick/n7MQUHa0vr4&t.mp4 (deflated 9%)
#   adding: content/MSData/val_cropped/yes/ (stored 0%)
#   adding: content/MSData/val_cropped/yes/0bIF7jh6lnE.mp4 (deflated 4%)
#   adding: content/MSData/val_cropped/yes/bX1eJjB3nyA.mp4 (deflated 1%)
#   adding: content/MSData/val_cropped/yes/gPlAfYvevxc.mp4 (deflated 2%)
#   adding: content/MSData/val_cropped/yes/g59_3vr_NT0.mp4 (deflated 20%)
#   adding: content/MSData/val_cropped/yes/kMO8kgPiQHY.mp4 (deflated 1%)
#   adding: content/MSData/val_cropped/yes/HUMEcnkvhJU&t.mp4 (deflated 10%)
#   adding: content/MSData/val_cropped/yes/-on_5PoBEak.mp4 (deflated 20%)
#   adding: content/MSData/val_cropped/yes/0v4Y9WGhES8.mp4 (deflated 13%)
#   adding: content/MSData/val_cropped/yes/5sILDEiOcQ0.mp4 (deflated 6%)
#   adding: content/MSData/val_cropped/yes/sQELZPmche8.mp4 (deflated 3%)
#   adding: content/MSData/val_cropped/fine/ (stored 0%)
#   adding: content/MSData/val_cropped/fine/cxXEULq9Jpc.mp4 (deflated 10%)
#   adding: content/MSData/val_cropped/fine/_LGqHR3FhL8.mp4 (deflated 15%)
#   adding: content/MSData/val_cropped/fine/Yey5VEZE-_g.mp4 (deflated 16%)
#   adding: content/MSData/val_cropped/fine/821mepSrKik.mp4 (deflated 1%)
#   adding: content/MSData/val_cropped/fine/f7tZegTJCWo.mp4 (deflated 5%)
#   adding: content/MSData/val_cropped/woman/ (stored 0%)
#   adding: content/MSData/val_cropped/woman/0bIF7jh6lnE.mp4 (deflated 2%)
#   adding: content/MSData/val_cropped/woman/KLD5f35qEDI&t.mp4 (deflated 10%)
#   adding: content/MSData/val_cropped/woman/2VB3WN8adyM.mp4 (deflated 5%)
#   adding: content/MSData/val_cropped/woman/BEKUHzwnVO8.mp4 (deflated 28%)
#   adding: content/MSData/val_cropped/woman/N4n5CDpyX3w.mp4 (deflated 20%)
#   adding: content/MSData/val_cropped/white/ (stored 0%)
#   adding: content/MSData/val_cropped/white/koMZVbqiXf4.mp4 (deflated 1%)
#   adding: content/MSData/val_cropped/white/Uu2prMSD4l4.mp4 (deflated 1%)
#   adding: content/MSData/val_cropped/white/hKogDJd0yc4.mp4 (deflated 19%)
#   adding: content/MSData/val_cropped/white/PHEFs5gHrl4.mp4 (deflated 1%)
#   adding: content/MSData/val_cropped/white/FRQbKDZeRzM.mp4 (deflated 4%)
#   adding: content/MSData/val_cropped/white/2VB3WN8adyM.mp4 (deflated 5%)
#   adding: content/MSData/val_cropped/white/VcRx3U-HpTE.mp4 (deflated 10%)
#   adding: content/MSData/val_cropped/white/n7MQUHa0vr4&t.mp4 (deflated 10%)
#   adding: content/MSData/val_cropped/day/ (stored 0%)
#   adding: content/MSData/val_cropped/day/KLD5f35qEDI&t.mp4 (deflated 12%)
#   adding: content/MSData/val_cropped/day/HUMEcnkvhJU&t.mp4 (deflated 9%)
#   adding: content/MSData/val_cropped/thank you/ (stored 0%)
#   adding: content/MSData/val_cropped/thank you/cxXEULq9Jpc.mp4 (deflated 9%)
#   adding: content/MSData/val_cropped/thank you/HUMEcnkvhJU&t.mp4 (deflated 8%)
#   adding: content/MSData/val_cropped/thank you/0v4Y9WGhES8.mp4 (deflated 13%)
#   adding: content/MSData/val_cropped/thank you/sQELZPmche8.mp4 (deflated 1%)
#   adding: content/MSData/val_cropped/english/ (stored 0%)
#   adding: content/MSData/val_cropped/english/cxXEULq9Jpc.mp4 (deflated 13%)
#   adding: content/MSData/val_cropped/english/qwBy3mikLAU.mp4 (deflated 19%)
#   adding: content/MSData/val_cropped/english/KLD5f35qEDI&t.mp4 (deflated 10%)
#   adding: content/MSData/val_cropped/english/W4W1TdB7zkU.mp4 (deflated 5%)
#   adding: content/MSData/val_cropped/father/ (stored 0%)
#   adding: content/MSData/val_cropped/father/dtSmDTn3zkk.mp4 (deflated 21%)
#   adding: content/MSData/val_cropped/father/7ECOJV4I3Gs.mp4 (deflated 3%)
#   adding: content/MSData/val_cropped/father/JYF-AfMbUNw.mp4 (deflated 1%)
#   adding: content/MSData/val_cropped/father/HUMEcnkvhJU&t.mp4 (deflated 7%)
#   adding: content/MSData/val_cropped/father/BEKUHzwnVO8.mp4 (deflated 17%)
#   adding: content/MSData/val_cropped/father/7m6N78E-5uE.mp4 (deflated 33%)
#   adding: content/MSData/val_cropped/father/psspxdbtM3k.mp4 (deflated 7%)
#   adding: content/MSData/val_cropped/father/n7MQUHa0vr4&t.mp4 (deflated 8%)
#   adding: content/MSData/val_cropped/draw/ (stored 0%)
#   adding: content/MSData/val_cropped/draw/KLD5f35qEDI&t.mp4 (deflated 12%)
#   adding: content/MSData/val_cropped/draw/bX1eJjB3nyA.mp4 (deflated 2%)
#   adding: content/MSData/val_cropped/draw/2VB3WN8adyM.mp4 (deflated 5%)
#   adding: content/MSData/val_cropped/what/ (stored 0%)
#   adding: content/MSData/val_cropped/what/cxXEULq9Jpc.mp4 (deflated 14%)
#   adding: content/MSData/val_cropped/what/_LGqHR3FhL8.mp4 (deflated 25%)
#   adding: content/MSData/val_cropped/what/2VB3WN8adyM.mp4 (deflated 4%)
#   adding: content/MSData/val_cropped/what/RjKI2a_hZ18.mp4 (deflated 1%)
#   adding: content/MSData/val_cropped/what/HUMEcnkvhJU&t.mp4 (deflated 12%)
#   adding: content/MSData/val_cropped/work/ (stored 0%)
#   adding: content/MSData/val_cropped/work/cxXEULq9Jpc.mp4 (deflated 11%)
#   adding: content/MSData/val_cropped/work/g59_3vr_NT0.mp4 (deflated 19%)
#   adding: content/MSData/val_cropped/work/EFTKM2dMkBE.mp4 (deflated 6%)
#   adding: content/MSData/val_cropped/work/HUMEcnkvhJU&t.mp4 (deflated 8%)
#   adding: content/MSData/val_cropped/work/1bj72qXSy8c.mp4 (deflated 10%)
#   adding: content/MSData/val_cropped/work/N4n5CDpyX3w.mp4 (deflated 21%)
#   adding: content/MSData/val_cropped/bird/ (stored 0%)
#   adding: content/MSData/val_cropped/bird/ic7JaMz2jmo.mp4 (deflated 4%)
#   adding: content/MSData/val_cropped/bird/KLD5f35qEDI&t.mp4 (deflated 10%)
#   adding: content/MSData/val_cropped/bird/mJ-GLSd8EHo.mp4 (deflated 1%)
#   adding: content/MSData/val_cropped/bird/pl2FLu62aSA.mp4 (deflated 4%)
#   adding: content/MSData/val_cropped/bird/rIlQQTN2b58.mp4 (deflated 12%)
#   adding: content/MSData/val_cropped/water/ (stored 0%)
#   adding: content/MSData/val_cropped/water/bX1eJjB3nyA.mp4 (deflated 1%)
#   adding: content/MSData/val_cropped/water/HHX-yrm-DMk.mp4 (deflated 28%)
#   adding: content/MSData/val_cropped/water/okqqixdZmE4.mp4 (deflated 1%)
#   adding: content/MSData/val_cropped/water/GmxS5HkNc3o.mp4 (deflated 4%)
#   adding: content/MSData/val_cropped/water/CmKYKBQuHf4.mp4 (deflated 11%)
#   adding: content/MSData/val_cropped/water/sQELZPmche8.mp4 (deflated 2%)
#   adding: content/MSData/val_cropped/chicken/ (stored 0%)
#   adding: content/MSData/val_cropped/chicken/CmKYKBQuHf4.mp4 (deflated 12%)
#   adding: content/MSData/val_cropped/chicken/He0k3ddd67A.mp4 (deflated 10%)
#   adding: content/MSData/val_cropped/sit/ (stored 0%)
#   adding: content/MSData/val_cropped/sit/0bIF7jh6lnE.mp4 (deflated 2%)
#   adding: content/MSData/val_cropped/sit/_LGqHR3FhL8.mp4 (deflated 19%)
#   adding: content/MSData/val_cropped/sit/KLD5f35qEDI&t.mp4 (deflated 6%)
#   adding: content/MSData/val_cropped/sit/bX1eJjB3nyA.mp4 (deflated 2%)
#   adding: content/MSData/val_cropped/sit/UTn4VLbe7Fg.mp4 (deflated 4%)
#   adding: content/MSData/val_cropped/sit/J9kZS0VdY_A&t.mp4 (deflated 13%)
#   adding: content/MSData/val_cropped/sit/v_SV_07Gcfk.mp4 (deflated 6%)
#   adding: content/MSData/val_cropped/sit/2VB3WN8adyM.mp4 (deflated 5%)
#   adding: content/MSData/val_cropped/sit/UjiCWH8PSvM.mp4 (deflated 10%)
#   adding: content/MSData/val_cropped/sit/f7tZegTJCWo.mp4 (deflated 13%)
#   adding: content/MSData/val_cropped/paper/ (stored 0%)
#   adding: content/MSData/val_cropped/paper/afwqCG7GmrQ.mp4 (deflated 9%)
#   adding: content/MSData/val_cropped/paper/2VB3WN8adyM.mp4 (deflated 5%)
#   adding: content/MSData/val_cropped/paper/9bosgmeAAuo.mp4 (deflated 16%)
#   adding: content/MSData/val_cropped/paper/UjiCWH8PSvM.mp4 (deflated 10%)
#   adding: content/MSData/val_cropped/paper/He0k3ddd67A.mp4 (deflated 9%)
#   adding: content/MSData/val_cropped/paper/n7MQUHa0vr4&t.mp4 (deflated 10%)
#   adding: content/MSData/val_cropped/paper/Zg-ygjairZQ.mp4 (deflated 5%)
#   adding: content/MSData/val_cropped/when/ (stored 0%)
#   adding: content/MSData/val_cropped/when/cxXEULq9Jpc.mp4 (deflated 11%)
#   adding: content/MSData/val_cropped/when/qQNwvAhwCuc.mp4 (deflated 1%)
#   adding: content/MSData/val_cropped/when/2VB3WN8adyM.mp4 (deflated 5%)
#   adding: content/MSData/val_cropped/when/HUMEcnkvhJU&t.mp4 (deflated 10%)
#   adding: content/MSData/val_cropped/hello/ (stored 0%)
#   adding: content/MSData/val_cropped/hello/2VB3WN8adyM.mp4 (deflated 7%)
#   adding: content/MSData/val_cropped/hello/xmM5-XsE8Ac.mp4 (deflated 1%)
#   adding: content/MSData/val_cropped/hello/HUMEcnkvhJU&t.mp4 (deflated 6%)
#   adding: content/MSData/val_cropped/hello/BEKUHzwnVO8.mp4 (deflated 14%)
#   adding: content/MSData/val_cropped/hello/0v4Y9WGhES8.mp4 (deflated 11%)
#   adding: content/MSData/val_cropped/hello/kZuJalsv_z0.mp4 (deflated 20%)
#   adding: content/MSData/val_cropped/tired/ (stored 0%)
#   adding: content/MSData/val_cropped/tired/cxXEULq9Jpc.mp4 (deflated 14%)
#   adding: content/MSData/val_cropped/tired/bX1eJjB3nyA.mp4 (deflated 1%)
#   adding: content/MSData/val_cropped/tired/eeHS78JyN70.mp4 (deflated 18%)
#   adding: content/MSData/val_cropped/tired/CxTSVyM-ij0.mp4 (deflated 13%)
#   adding: content/MSData/val_cropped/tired/qdC7SfVp8iQ.mp4 (deflated 18%)
#   adding: content/MSData/val_cropped/tired/PBDUwwE9BFM&t.mp4 (deflated 1%)
#   adding: content/MSData/val_cropped/tired/R_G5zGVHxkU.mp4 (deflated 33%)
#   adding: content/MSData/val_cropped/tired/kZuJalsv_z0.mp4 (deflated 22%)
#   adding: content/MSData/val_cropped/spring/ (stored 0%)
#   adding: content/MSData/val_cropped/spring/n0PdKty8WRA.mp4 (deflated 4%)
#   adding: content/MSData/val_cropped/spring/2ofPs_uTel4.mp4 (deflated 2%)
#   adding: content/MSData/val_cropped/spring/J9kZS0VdY_A&t.mp4 (deflated 10%)
#   adding: content/MSData/val_cropped/spring/UjiCWH8PSvM.mp4 (deflated 8%)
#   adding: content/MSData/val_cropped/spring/dELt8wh_5nA&t.mp4 (deflated 7%)
#   adding: content/MSData/val_cropped/need/ (stored 0%)
#   adding: content/MSData/val_cropped/need/_LGqHR3FhL8.mp4 (deflated 25%)
#   adding: content/MSData/val_cropped/need/KLD5f35qEDI&t.mp4 (deflated 13%)
#   adding: content/MSData/val_cropped/pink/ (stored 0%)
#   adding: content/MSData/val_cropped/pink/koMZVbqiXf4.mp4 (deflated 1%)
#   adding: content/MSData/val_cropped/pink/hKogDJd0yc4.mp4 (deflated 18%)
#   adding: content/MSData/val_cropped/pink/2VB3WN8adyM.mp4 (deflated 4%)
#   adding: content/MSData/val_cropped/pink/b4CVpVEes1g.mp4 (deflated 1%)
#   adding: content/MSData/val_cropped/pink/n7MQUHa0vr4&t.mp4 (deflated 14%)
#   adding: content/MSData/val_cropped/big/ (stored 0%)
#   adding: content/MSData/val_cropped/big/TR9M0q7iWxY.mp4 (deflated 1%)
#   adding: content/MSData/val_cropped/big/J9kZS0VdY_A&t.mp4 (deflated 19%)
#   adding: content/MSData/val_cropped/big/FRQbKDZeRzM.mp4 (deflated 4%)
#   adding: content/MSData/val_cropped/big/HUMEcnkvhJU&t.mp4 (deflated 7%)
#   adding: content/MSData/val_cropped/big/bTSejTfpGR8.mp4 (deflated 1%)
#   adding: content/MSData/val_cropped/big/5sILDEiOcQ0.mp4 (deflated 6%)
#   adding: content/MSData/val_cropped/big/kZuJalsv_z0.mp4 (deflated 20%)
#   adding: content/MSData/val_cropped/live/ (stored 0%)
#   adding: content/MSData/val_cropped/live/KLD5f35qEDI&t.mp4 (deflated 11%)
#   adding: content/MSData/val_cropped/live/n0PdKty8WRA.mp4 (deflated 7%)
#   adding: content/MSData/val_cropped/live/J9kZS0VdY_A&t.mp4 (deflated 11%)
#   adding: content/MSData/val_cropped/live/BEKUHzwnVO8.mp4 (deflated 12%)
#   adding: content/MSData/val_cropped/live/jp3sQrnQYzs.mp4 (deflated 1%)
#   adding: content/MSData/val_cropped/yellow/ (stored 0%)
#   adding: content/MSData/val_cropped/yellow/koMZVbqiXf4.mp4 (deflated 1%)
#   adding: content/MSData/val_cropped/yellow/2VB3WN8adyM.mp4 (deflated 4%)
#   adding: content/MSData/val_cropped/yellow/Ji0_VUFdAVY.mp4 (deflated 2%)
#   adding: content/MSData/val_cropped/yellow/Zwk1zkBU2UE.mp4 (deflated 1%)
#   adding: content/MSData/val_cropped/yellow/n7MQUHa0vr4&t.mp4 (deflated 9%)
#   adding: content/MSData/val_cropped/hearing/ (stored 0%)
#   adding: content/MSData/val_cropped/hearing/cxXEULq9Jpc.mp4 (deflated 14%)
#   adding: content/MSData/val_cropped/hearing/0bIF7jh6lnE.mp4 (deflated 2%)
#   adding: content/MSData/val_cropped/hearing/9jy2ywb8eAU.mp4 (deflated 1%)
#   adding: content/MSData/val_cropped/hearing/x5cwBfSKnZc.mp4 (deflated 21%)
#   adding: content/MSData/val_cropped/hearing/kZuJalsv_z0.mp4 (deflated 19%)
#   adding: content/MSData/val_cropped/book/ (stored 0%)
#   adding: content/MSData/val_cropped/book/aGtIHKEdCds.mp4 (deflated 27%)
#   adding: content/MSData/val_cropped/book/KLD5f35qEDI&t.mp4 (deflated 8%)
#   adding: content/MSData/val_cropped/book/BOKcZa6mugU.mp4 (deflated 2%)
#   adding: content/MSData/val_cropped/book/afwqCG7GmrQ.mp4 (deflated 4%)
#   adding: content/MSData/val_cropped/book/2VB3WN8adyM.mp4 (deflated 4%)
#   adding: content/MSData/val_cropped/book/9bosgmeAAuo.mp4 (deflated 14%)
#   adding: content/MSData/val_cropped/book/UjiCWH8PSvM.mp4 (deflated 4%)
#   adding: content/MSData/val_cropped/book/GmxS5HkNc3o.mp4 (deflated 4%)
#   adding: content/MSData/val_cropped/bad/ (stored 0%)
#   adding: content/MSData/val_cropped/bad/bX1eJjB3nyA.mp4 (deflated 1%)
#   adding: content/MSData/val_cropped/bad/hKogDJd0yc4.mp4 (deflated 16%)
#   adding: content/MSData/val_cropped/bad/FRQbKDZeRzM.mp4 (deflated 7%)
#   adding: content/MSData/val_cropped/bad/rIlQQTN2b58.mp4 (deflated 11%)
#   adding: content/MSData/val_cropped/bad/HUMEcnkvhJU&t.mp4 (deflated 4%)
#   adding: content/MSData/val_cropped/bad/0v4Y9WGhES8.mp4 (deflated 7%)
#   adding: content/MSData/val_cropped/bad/mz32w4pNLLI.mp4 (deflated 1%)
#   adding: content/MSData/val_cropped/forget/ (stored 0%)
#   adding: content/MSData/val_cropped/forget/0bIF7jh6lnE.mp4 (deflated 2%)
#   adding: content/MSData/val_cropped/forget/KLD5f35qEDI&t.mp4 (deflated 9%)
# ...
#   adding: content/MSData/val/play/ (stored 0%)
#   adding: content/MSData/val/play/bX1eJjB3nyA.mp4 (deflated 3%)
#   adding: content/MSData/val/play/M80w0mda7zM.mp4 (deflated 1%)
#   adding: content/MSData/val/play/J9kZS0VdY_A&t.mp4 (deflated 2%)
#   adding: content/MSData/val/play/ws12ZoG4qAU.mp4 (deflated 0%)
#   adding: content/MSData/val/play/1bj72qXSy8c.mp4 (deflated 0%)
#   adding: content/MSData/val/write/ (stored 0%)
#   adding: content/MSData/val/write/KLD5f35qEDI&t.mp4 (deflated 1%)
#   adding: content/MSData/val/write/bX1eJjB3nyA.mp4 (deflated 2%)
#   adding: content/MSData/val/write/afwqCG7GmrQ.mp4 (deflated 1%)
#   adding: content/MSData/val/write/2VB3WN8adyM.mp4 (deflated 0%)
#   adding: content/MSData/val/lost/ (stored 0%)
#   adding: content/MSData/val/lost/-IEFUtDrWCg.mp4 (deflated 3%)
#   adding: content/MSData/val/lost/J9kZS0VdY_A&t.mp4 (deflated 2%)
#   adding: content/MSData/val/lost/fii2boOPUnY.mp4 (deflated 3%)
#   adding: content/MSData/val/lost/dELt8wh_5nA&t.mp4 (deflated 0%)
#   adding: content/MSData/val/lost/N4n5CDpyX3w.mp4 (deflated 2%)
#   adding: content/MSData/val/lost/6cqY0BbfE80.mp4 (deflated 1%)
#   adding: content/MSData/val/mother/ (stored 0%)
#   adding: content/MSData/val/mother/dtSmDTn3zkk.mp4 (deflated 0%)
#   adding: content/MSData/val/mother/c5a0wBqihes.mp4 (deflated 6%)
#   adding: content/MSData/val/mother/JYF-AfMbUNw.mp4 (deflated 2%)
#   adding: content/MSData/val/mother/HUMEcnkvhJU&t.mp4 (deflated 1%)
#   adding: content/MSData/val/mother/BEKUHzwnVO8.mp4 (deflated 1%)
#   adding: content/MSData/val/mother/7m6N78E-5uE.mp4 (deflated 2%)
#   adding: content/MSData/val/mother/psspxdbtM3k.mp4 (deflated 1%)
#   adding: content/MSData/val/mother/n7MQUHa0vr4&t.mp4 (deflated 2%)
#   adding: content/MSData/val/know/ (stored 0%)
#   adding: content/MSData/val/know/cxXEULq9Jpc.mp4 (deflated 1%)
#   adding: content/MSData/val/know/0bIF7jh6lnE.mp4 (deflated 2%)
#   adding: content/MSData/val/know/CxTSVyM-ij0.mp4 (deflated 2%)
#   adding: content/MSData/val/know/HUMEcnkvhJU&t.mp4 (deflated 1%)
#   adding: content/MSData/val/know/BEKUHzwnVO8.mp4 (deflated 1%)
#   adding: content/MSData/val/know/0v4Y9WGhES8.mp4 (deflated 1%)
#   adding: content/MSData/val/finish/ (stored 0%)
#   adding: content/MSData/val/finish/bX1eJjB3nyA.mp4 (deflated 2%)
#   adding: content/MSData/val/finish/dtSmDTn3zkk.mp4 (deflated 0%)
#   adding: content/MSData/val/finish/JDc62QM6-GU.mp4 (deflated 1%)
#   adding: content/MSData/val/finish/J9kZS0VdY_A&t.mp4 (deflated 1%)
#   adding: content/MSData/val/finish/GmxS5HkNc3o.mp4 (deflated 1%)
#   adding: content/MSData/val/finish/HUMEcnkvhJU&t.mp4 (deflated 1%)
#   adding: content/MSData/val/finish/1bj72qXSy8c.mp4 (deflated 0%)
#   adding: content/MSData/val/finish/f7tZegTJCWo.mp4 (deflated 0%)
#   adding: content/MSData/val/beautiful/ (stored 0%)
#   adding: content/MSData/val/beautiful/hKogDJd0yc4.mp4 (deflated 0%)
#   adding: content/MSData/val/beautiful/J9kZS0VdY_A&t.mp4 (deflated 2%)
#   adding: content/MSData/val/beautiful/qE0EsE4dTj8.mp4 (deflated 3%)
#   adding: content/MSData/val/beautiful/rIlQQTN2b58.mp4 (deflated 0%)
#   adding: content/MSData/val/beautiful/kZuJalsv_z0.mp4 (deflated 1%)
#   adding: content/MSData/val/here/ (stored 0%)
#   adding: content/MSData/val/here/koMZVbqiXf4.mp4 (deflated 2%)
#   adding: content/MSData/val/here/KLD5f35qEDI&t.mp4 (deflated 1%)
#   adding: content/MSData/val/here/9bosgmeAAuo.mp4 (deflated 0%)
#   adding: content/MSData/val/here/HUMEcnkvhJU&t.mp4 (deflated 1%)
#   adding: content/MSData/val/here/JBIstMmmHxI.mp4 (deflated 0%)
#   adding: content/MSData/val/sick/ (stored 0%)
#   adding: content/MSData/val/sick/bX1eJjB3nyA.mp4 (deflated 3%)
#   adding: content/MSData/val/sick/g59_3vr_NT0.mp4 (deflated 1%)
#   adding: content/MSData/val/sick/CxTSVyM-ij0.mp4 (deflated 2%)
#   adding: content/MSData/val/sick/bS9icDOS5g4.mp4 (deflated 0%)
#   adding: content/MSData/val/sick/1bj72qXSy8c.mp4 (deflated 0%)
#   adding: content/MSData/val/sick/n7MQUHa0vr4&t.mp4 (deflated 1%)
#   adding: content/MSData/val/yes/ (stored 0%)
#   adding: content/MSData/val/yes/0bIF7jh6lnE.mp4 (deflated 2%)
#   adding: content/MSData/val/yes/bX1eJjB3nyA.mp4 (deflated 3%)
#   adding: content/MSData/val/yes/gPlAfYvevxc.mp4 (deflated 2%)
#   adding: content/MSData/val/yes/g59_3vr_NT0.mp4 (deflated 1%)
#   adding: content/MSData/val/yes/kMO8kgPiQHY.mp4 (deflated 3%)
#   adding: content/MSData/val/yes/HUMEcnkvhJU&t.mp4 (deflated 1%)
#   adding: content/MSData/val/yes/-on_5PoBEak.mp4 (deflated 1%)
#   adding: content/MSData/val/yes/0v4Y9WGhES8.mp4 (deflated 2%)
#   adding: content/MSData/val/yes/5sILDEiOcQ0.mp4 (deflated 0%)
#   adding: content/MSData/val/yes/sQELZPmche8.mp4 (deflated 4%)
#   adding: content/MSData/val/fine/ (stored 0%)
#   adding: content/MSData/val/fine/cxXEULq9Jpc.mp4 (deflated 1%)
#   adding: content/MSData/val/fine/_LGqHR3FhL8.mp4 (deflated 0%)
#   adding: content/MSData/val/fine/Yey5VEZE-_g.mp4 (deflated 1%)
#   adding: content/MSData/val/fine/821mepSrKik.mp4 (deflated 4%)
#   adding: content/MSData/val/fine/f7tZegTJCWo.mp4 (deflated 1%)
#   adding: content/MSData/val/woman/ (stored 0%)
#   adding: content/MSData/val/woman/0bIF7jh6lnE.mp4 (deflated 2%)
#   adding: content/MSData/val/woman/KLD5f35qEDI&t.mp4 (deflated 1%)
#   adding: content/MSData/val/woman/2VB3WN8adyM.mp4 (deflated 1%)
#   adding: content/MSData/val/woman/BEKUHzwnVO8.mp4 (deflated 1%)
#   adding: content/MSData/val/woman/N4n5CDpyX3w.mp4 (deflated 2%)
#   adding: content/MSData/val/white/ (stored 0%)
#   adding: content/MSData/val/white/koMZVbqiXf4.mp4 (deflated 2%)
#   adding: content/MSData/val/white/Uu2prMSD4l4.mp4 (deflated 5%)
#   adding: content/MSData/val/white/hKogDJd0yc4.mp4 (deflated 0%)
#   adding: content/MSData/val/white/PHEFs5gHrl4.mp4 (deflated 4%)
#   adding: content/MSData/val/white/FRQbKDZeRzM.mp4 (deflated 4%)
#   adding: content/MSData/val/white/2VB3WN8adyM.mp4 (deflated 0%)
#   adding: content/MSData/val/white/VcRx3U-HpTE.mp4 (deflated 1%)
#   adding: content/MSData/val/white/n7MQUHa0vr4&t.mp4 (deflated 1%)
#   adding: content/MSData/val/day/ (stored 0%)
#   adding: content/MSData/val/day/KLD5f35qEDI&t.mp4 (deflated 1%)
#   adding: content/MSData/val/day/HUMEcnkvhJU&t.mp4 (deflated 1%)
#   adding: content/MSData/val/thank you/ (stored 0%)
#   adding: content/MSData/val/thank you/cxXEULq9Jpc.mp4 (deflated 1%)
#   adding: content/MSData/val/thank you/HUMEcnkvhJU&t.mp4 (deflated 1%)
#   adding: content/MSData/val/thank you/0v4Y9WGhES8.mp4 (deflated 1%)
#   adding: content/MSData/val/thank you/sQELZPmche8.mp4 (deflated 3%)
#   adding: content/MSData/val/english/ (stored 0%)
#   adding: content/MSData/val/english/cxXEULq9Jpc.mp4 (deflated 1%)
#   adding: content/MSData/val/english/qwBy3mikLAU.mp4 (deflated 1%)
#   adding: content/MSData/val/english/KLD5f35qEDI&t.mp4 (deflated 1%)
#   adding: content/MSData/val/english/W4W1TdB7zkU.mp4 (deflated 0%)
#   adding: content/MSData/val/father/ (stored 0%)
#   adding: content/MSData/val/father/dtSmDTn3zkk.mp4 (deflated 0%)
#   adding: content/MSData/val/father/7ECOJV4I3Gs.mp4 (deflated 3%)
#   adding: content/MSData/val/father/JYF-AfMbUNw.mp4 (deflated 2%)
#   adding: content/MSData/val/father/HUMEcnkvhJU&t.mp4 (deflated 1%)
#   adding: content/MSData/val/father/BEKUHzwnVO8.mp4 (deflated 1%)
#   adding: content/MSData/val/father/7m6N78E-5uE.mp4 (deflated 2%)
#   adding: content/MSData/val/father/psspxdbtM3k.mp4 (deflated 1%)
#   adding: content/MSData/val/father/n7MQUHa0vr4&t.mp4 (deflated 1%)
#   adding: content/MSData/val/draw/ (stored 0%)
#   adding: content/MSData/val/draw/KLD5f35qEDI&t.mp4 (deflated 1%)
#   adding: content/MSData/val/draw/bX1eJjB3nyA.mp4 (deflated 3%)
#   adding: content/MSData/val/draw/2VB3WN8adyM.mp4 (deflated 1%)
#   adding: content/MSData/val/what/ (stored 0%)
#   adding: content/MSData/val/what/cxXEULq9Jpc.mp4 (deflated 1%)
#   adding: content/MSData/val/what/_LGqHR3FhL8.mp4 (deflated 0%)
#   adding: content/MSData/val/what/2VB3WN8adyM.mp4 (deflated 0%)
#   adding: content/MSData/val/what/RjKI2a_hZ18.mp4 (deflated 3%)
#   adding: content/MSData/val/what/HUMEcnkvhJU&t.mp4 (deflated 1%)
#   adding: content/MSData/val/work/ (stored 0%)
#   adding: content/MSData/val/work/cxXEULq9Jpc.mp4 (deflated 1%)
#   adding: content/MSData/val/work/g59_3vr_NT0.mp4 (deflated 1%)
#   adding: content/MSData/val/work/EFTKM2dMkBE.mp4 (deflated 1%)
#   adding: content/MSData/val/work/HUMEcnkvhJU&t.mp4 (deflated 1%)
#   adding: content/MSData/val/work/1bj72qXSy8c.mp4 (deflated 0%)
#   adding: content/MSData/val/work/N4n5CDpyX3w.mp4 (deflated 2%)
#   adding: content/MSData/val/bird/ (stored 0%)
#   adding: content/MSData/val/bird/ic7JaMz2jmo.mp4 (deflated 2%)
#   adding: content/MSData/val/bird/KLD5f35qEDI&t.mp4 (deflated 1%)
#   adding: content/MSData/val/bird/mJ-GLSd8EHo.mp4 (deflated 3%)
#   adding: content/MSData/val/bird/pl2FLu62aSA.mp4 (deflated 1%)
#   adding: content/MSData/val/bird/rIlQQTN2b58.mp4 (deflated 0%)
#   adding: content/MSData/val/water/ (stored 0%)
#   adding: content/MSData/val/water/bX1eJjB3nyA.mp4 (deflated 3%)
#   adding: content/MSData/val/water/HHX-yrm-DMk.mp4 (deflated 1%)
#   adding: content/MSData/val/water/okqqixdZmE4.mp4 (deflated 4%)
#   adding: content/MSData/val/water/GmxS5HkNc3o.mp4 (deflated 2%)
#   adding: content/MSData/val/water/CmKYKBQuHf4.mp4 (deflated 1%)
#   adding: content/MSData/val/water/sQELZPmche8.mp4 (deflated 4%)
#   adding: content/MSData/val/chicken/ (stored 0%)
#   adding: content/MSData/val/chicken/CmKYKBQuHf4.mp4 (deflated 1%)
#   adding: content/MSData/val/chicken/He0k3ddd67A.mp4 (deflated 0%)
#   adding: content/MSData/val/sit/ (stored 0%)
#   adding: content/MSData/val/sit/0bIF7jh6lnE.mp4 (deflated 3%)
#   adding: content/MSData/val/sit/_LGqHR3FhL8.mp4 (deflated 0%)
#   adding: content/MSData/val/sit/KLD5f35qEDI&t.mp4 (deflated 1%)
#   adding: content/MSData/val/sit/bX1eJjB3nyA.mp4 (deflated 3%)
#   adding: content/MSData/val/sit/UTn4VLbe7Fg.mp4 (deflated 4%)
#   adding: content/MSData/val/sit/J9kZS0VdY_A&t.mp4 (deflated 2%)
#   adding: content/MSData/val/sit/v_SV_07Gcfk.mp4 (deflated 1%)
#   adding: content/MSData/val/sit/2VB3WN8adyM.mp4 (deflated 0%)
#   adding: content/MSData/val/sit/UjiCWH8PSvM.mp4 (deflated 1%)
#   adding: content/MSData/val/sit/f7tZegTJCWo.mp4 (deflated 0%)
#   adding: content/MSData/val/paper/ (stored 0%)
#   adding: content/MSData/val/paper/afwqCG7GmrQ.mp4 (deflated 1%)
#   adding: content/MSData/val/paper/2VB3WN8adyM.mp4 (deflated 0%)
#   adding: content/MSData/val/paper/9bosgmeAAuo.mp4 (deflated 0%)
#   adding: content/MSData/val/paper/UjiCWH8PSvM.mp4 (deflated 1%)
#   adding: content/MSData/val/paper/He0k3ddd67A.mp4 (deflated 0%)
#   adding: content/MSData/val/paper/n7MQUHa0vr4&t.mp4 (deflated 1%)
#   adding: content/MSData/val/paper/Zg-ygjairZQ.mp4 (deflated 2%)
#   adding: content/MSData/val/when/ (stored 0%)
#   adding: content/MSData/val/when/cxXEULq9Jpc.mp4 (deflated 1%)
#   adding: content/MSData/val/when/qQNwvAhwCuc.mp4 (deflated 3%)
#   adding: content/MSData/val/when/2VB3WN8adyM.mp4 (deflated 0%)
#   adding: content/MSData/val/when/HUMEcnkvhJU&t.mp4 (deflated 1%)
#   adding: content/MSData/val/hello/ (stored 0%)
#   adding: content/MSData/val/hello/2VB3WN8adyM.mp4 (deflated 0%)
#   adding: content/MSData/val/hello/xmM5-XsE8Ac.mp4 (deflated 3%)
#   adding: content/MSData/val/hello/HUMEcnkvhJU&t.mp4 (deflated 1%)
#   adding: content/MSData/val/hello/BEKUHzwnVO8.mp4 (deflated 1%)
#   adding: content/MSData/val/hello/0v4Y9WGhES8.mp4 (deflated 1%)
#   adding: content/MSData/val/hello/kZuJalsv_z0.mp4 (deflated 1%)
#   adding: content/MSData/val/tired/ (stored 0%)
#   adding: content/MSData/val/tired/cxXEULq9Jpc.mp4 (deflated 1%)
#   adding: content/MSData/val/tired/bX1eJjB3nyA.mp4 (deflated 3%)
#   adding: content/MSData/val/tired/eeHS78JyN70.mp4 (deflated 1%)
#   adding: content/MSData/val/tired/CxTSVyM-ij0.mp4 (deflated 1%)
#   adding: content/MSData/val/tired/qdC7SfVp8iQ.mp4 (deflated 1%)
#   adding: content/MSData/val/tired/PBDUwwE9BFM&t.mp4 (deflated 1%)
#   adding: content/MSData/val/tired/R_G5zGVHxkU.mp4 (deflated 2%)
#   adding: content/MSData/val/tired/kZuJalsv_z0.mp4 (deflated 1%)
#   adding: content/MSData/val/spring/ (stored 0%)
#   adding: content/MSData/val/spring/n0PdKty8WRA.mp4 (deflated 1%)
#   adding: content/MSData/val/spring/2ofPs_uTel4.mp4 (deflated 0%)
#   adding: content/MSData/val/spring/J9kZS0VdY_A&t.mp4 (deflated 1%)
#   adding: content/MSData/val/spring/UjiCWH8PSvM.mp4 (deflated 1%)
#   adding: content/MSData/val/spring/dELt8wh_5nA&t.mp4 (deflated 1%)
#   adding: content/MSData/val/need/ (stored 0%)
#   adding: content/MSData/val/need/_LGqHR3FhL8.mp4 (deflated 0%)
#   adding: content/MSData/val/need/KLD5f35qEDI&t.mp4 (deflated 1%)
#   adding: content/MSData/val/pink/ (stored 0%)
#   adding: content/MSData/val/pink/koMZVbqiXf4.mp4 (deflated 3%)
#   adding: content/MSData/val/pink/hKogDJd0yc4.mp4 (deflated 0%)
#   adding: content/MSData/val/pink/2VB3WN8adyM.mp4 (deflated 0%)
#   adding: content/MSData/val/pink/b4CVpVEes1g.mp4 (deflated 4%)
#   adding: content/MSData/val/pink/n7MQUHa0vr4&t.mp4 (deflated 1%)
#   adding: content/MSData/val/big/ (stored 0%)
#   adding: content/MSData/val/big/TR9M0q7iWxY.mp4 (deflated 4%)
#   adding: content/MSData/val/big/J9kZS0VdY_A&t.mp4 (deflated 2%)
#   adding: content/MSData/val/big/FRQbKDZeRzM.mp4 (deflated 3%)
#   adding: content/MSData/val/big/HUMEcnkvhJU&t.mp4 (deflated 1%)
#   adding: content/MSData/val/big/bTSejTfpGR8.mp4 (deflated 4%)
#   adding: content/MSData/val/big/5sILDEiOcQ0.mp4 (deflated 1%)
#   adding: content/MSData/val/big/kZuJalsv_z0.mp4 (deflated 1%)
#   adding: content/MSData/val/live/ (stored 0%)
#   adding: content/MSData/val/live/KLD5f35qEDI&t.mp4 (deflated 1%)
#   adding: content/MSData/val/live/n0PdKty8WRA.mp4 (deflated 1%)
#   adding: content/MSData/val/live/J9kZS0VdY_A&t.mp4 (deflated 2%)
#   adding: content/MSData/val/live/BEKUHzwnVO8.mp4 (deflated 1%)
#   adding: content/MSData/val/live/jp3sQrnQYzs.mp4 (deflated 4%)
#   adding: content/MSData/val/yellow/ (stored 0%)
#   adding: content/MSData/val/yellow/koMZVbqiXf4.mp4 (deflated 2%)
#   adding: content/MSData/val/yellow/2VB3WN8adyM.mp4 (deflated 0%)
#   adding: content/MSData/val/yellow/Ji0_VUFdAVY.mp4 (deflated 5%)
#   adding: content/MSData/val/yellow/Zwk1zkBU2UE.mp4 (deflated 3%)
#   adding: content/MSData/val/yellow/n7MQUHa0vr4&t.mp4 (deflated 1%)
#   adding: content/MSData/val/hearing/ (stored 0%)
#   adding: content/MSData/val/hearing/cxXEULq9Jpc.mp4 (deflated 1%)
#   adding: content/MSData/val/hearing/0bIF7jh6lnE.mp4 (deflated 2%)
#   adding: content/MSData/val/hearing/9jy2ywb8eAU.mp4 (deflated 5%)
#   adding: content/MSData/val/hearing/x5cwBfSKnZc.mp4 (deflated 0%)
#   adding: content/MSData/val/hearing/kZuJalsv_z0.mp4 (deflated 1%)
#   adding: content/MSData/val/book/ (stored 0%)
#   adding: content/MSData/val/book/aGtIHKEdCds.mp4 (deflated 1%)
#   adding: content/MSData/val/book/KLD5f35qEDI&t.mp4 (deflated 1%)
#   adding: content/MSData/val/book/BOKcZa6mugU.mp4 (deflated 4%)
#   adding: content/MSData/val/book/afwqCG7GmrQ.mp4 (deflated 1%)
#   adding: content/MSData/val/book/2VB3WN8adyM.mp4 (deflated 0%)
#   adding: content/MSData/val/book/9bosgmeAAuo.mp4 (deflated 0%)
#   adding: content/MSData/val/book/UjiCWH8PSvM.mp4 (deflated 1%)
#   adding: content/MSData/val/book/GmxS5HkNc3o.mp4 (deflated 1%)
#   adding: content/MSData/val/bad/ (stored 0%)
#   adding: content/MSData/val/bad/bX1eJjB3nyA.mp4 (deflated 3%)
#   adding: content/MSData/val/bad/hKogDJd0yc4.mp4 (deflated 0%)
#   adding: content/MSData/val/bad/FRQbKDZeRzM.mp4 (deflated 4%)
#   adding: content/MSData/val/bad/rIlQQTN2b58.mp4 (deflated 0%)
#   adding: content/MSData/val/bad/HUMEcnkvhJU&t.mp4 (deflated 1%)
#   adding: content/MSData/val/bad/0v4Y9WGhES8.mp4 (deflated 2%)
#   adding: content/MSData/val/bad/mz32w4pNLLI.mp4 (deflated 4%)
#   adding: content/MSData/val/forget/ (stored 0%)
#   adding: content/MSData/val/forget/0bIF7jh6lnE.mp4 (deflated 3%)
#   adding: content/MSData/val/forget/KLD5f35qEDI&t.mp4 (deflated 1%)
#   adding: content/MSData/val/forget/IlIE1OP3gP0&t.mp4 (deflated 0%)
#   adding: content/MSData/val/forget/PBDUwwE9BFM&t.mp4 (deflated 1%)
#   adding: content/MSData/val/forget/l_aBsu7kVqI.mp4 (deflated 1%)
#   adding: content/MSData/val/forget/0v4Y9WGhES8.mp4 (deflated 1%)
#   adding: content/MSData/val/forget/N4n5CDpyX3w.mp4 (deflated 2%)

# %%
# !zip -r drive/MyDrive/SignLanguage/MSDataPictures.zip /content/MS_Data_Pictures
